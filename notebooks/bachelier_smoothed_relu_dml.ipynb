# %% [markdown]
# # Bachelier

# %% [markdown]
# We consider the Bachelier model for a call option with European payoff $(S_T - K)^+$:
#
# $$
# d{F_t} = \sigma d{W_t},
# $$
#
# where:
# - $d{W_t}$ denotes a Wiener process
# - $\sigma$ is the constant volatility
#
# This is a simplified view using a forward measure and forward price: $F_t=S_t e^{r(T-t)}$, where $r$ is the risk-free interest rate.
#
# Furthermore, consider Gaussian basket: $$F_t = \sum_{i=0}^{m} \omega_i F^{[i]}_t.$$
# It is a weighted sum of the underlying jointly Gaussian distributed assets.
# Unlike lognormally distributed prices, the basket price $F_t$ is again Gaussian.
# That is why the Bachelier model is again applicable.
#
# In the following code the spot and forward price are used interchangibly.

# %% [markdown]
# We can discretize this SDE using, e.g., the Euler-Maryuama scheme. Then the samples for training are computed using Monte Carlo and the pathwise derivative method.

# %% [markdown]
# # General Imports and Settings

# %%
# Make sure the following packages are installed:
# matplotlib, numpy, jaxlib, jax, jaxtyping, optax, chex, tensorflow, tensorflow-datasets

# %pip install matplotlib
# %pip install numpy

# install required jax packages
# %pip install --upgrade "jax[cuda11_local]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# %pip install equinox jaxtyping optax chex

# install tensorflow datasets for data loading
# %pip install tensorflow
# %pip install tensorflow-datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (1.24.4)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Requirement already satisfied: jax[cuda11_local] in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (0.4.20)
# WARNING: jax 0.4.20 does not provide the extra 'cuda11-local'
# Requirement already satisfied: ml-dtypes>=0.2.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax[cuda11_local]) (0.2.0)
# Requirement already satisfied: numpy>=1.22 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax[cuda11_local]) (1.24.4)
# Requirement already satisfied: opt-einsum in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax[cuda11_local]) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from jax[cuda11_local]) (1.9.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from jax[cuda11_local]) (4.11.4)
# Requirement already satisfied: jaxlib==0.4.20+cuda11.cudnn86 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax[cuda11_local]) (0.4.20+cuda11.cudnn86)
# Requirement already satisfied: zipp>=0.5 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax[cuda11_local]) (3.8.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: equinox in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: jaxtyping in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (0.2.23)
# Requirement already satisfied: optax in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (0.1.7)
# Requirement already satisfied: chex in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (0.1.83)
# Requirement already satisfied: jax>=0.4.13 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from equinox) (0.4.20)
# Requirement already satisfied: typing-extensions>=4.5.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from equinox) (4.8.0)
# Requirement already satisfied: numpy>=1.20.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jaxtyping) (1.24.4)
# Requirement already satisfied: typeguard<3,>=2.13.3 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jaxtyping) (2.13.3)
# Requirement already satisfied: absl-py>=0.7.1 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from optax) (1.4.0)
# Requirement already satisfied: jaxlib>=0.1.37 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from optax) (0.4.20+cuda11.cudnn86)
# Requirement already satisfied: toolz>=0.9.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from chex) (0.12.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (0.2.0)
# Requirement already satisfied: opt-einsum in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (1.9.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax>=0.4.13->equinox) (3.8.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (1.24.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorflow) (62.3.2)
# Requirement already satisfied: six>=1.12.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.15,>=2.14->tensorflow) (4.11.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.15,>=2.14->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-datasets in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (4.9.3)
# Requirement already satisfied: absl-py in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (1.4.0)
# Requirement already satisfied: array-record in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (0.5.0)
# Requirement already satisfied: click in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorflow-datasets) (8.1.3)
# Requirement already satisfied: dm-tree in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (0.1.8)
# Requirement already satisfied: etils>=0.9.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (1.5.2)
# Requirement already satisfied: numpy in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (1.24.4)
# Requirement already satisfied: promise in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (3.20.3)
# Requirement already satisfied: psutil in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorflow-datasets) (5.9.2)
# Requirement already satisfied: requests>=2.19.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorflow-datasets) (2.27.1)
# Requirement already satisfied: tensorflow-metadata in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (1.14.0)
# Requirement already satisfied: termcolor in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (2.3.0)
# Requirement already satisfied: toml in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from tensorflow-datasets) (4.64.1)
# Requirement already satisfied: wrapt in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-datasets) (1.14.1)
# Requirement already satisfied: fsspec in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (2023.6.0)
# Requirement already satisfied: importlib_resources in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (5.7.1)
# Requirement already satisfied: typing_extensions in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (4.8.0)
# Requirement already satisfied: zipp in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (3.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests>=2.19.0->tensorflow-datasets) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests>=2.19.0->tensorflow-datasets) (2022.9.14)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests>=2.19.0->tensorflow-datasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from requests>=2.19.0->tensorflow-datasets) (3.3)
# Requirement already satisfied: six in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from promise->tensorflow-datasets) (1.16.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from tensorflow-metadata->tensorflow-datasets) (1.61.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# For Google Colab
# %pip install jaxtyping
# %pip install equinox
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jaxtyping in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (0.2.23)
# Requirement already satisfied: numpy>=1.20.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jaxtyping) (1.24.4)
# Requirement already satisfied: typeguard<3,>=2.13.3 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jaxtyping) (2.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jaxtyping) (4.8.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: equinox in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: jax>=0.4.13 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from equinox) (0.4.20)
# Requirement already satisfied: jaxtyping>=0.2.20 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from equinox) (0.2.23)
# Requirement already satisfied: typing-extensions>=4.5.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from equinox) (4.8.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (0.2.0)
# Requirement already satisfied: numpy>=1.22 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (1.24.4)
# Requirement already satisfied: opt-einsum in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (1.9.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from jax>=0.4.13->equinox) (4.11.4)
# Requirement already satisfied: typeguard<3,>=2.13.3 in /rwthfs/rz/cluster/home/fc202177/.local/lib/python3.9/site-packages (from jaxtyping>=0.2.20->equinox) (2.13.3)
# Requirement already satisfied: zipp>=0.5 in /cvmfs/sys.hpc.itc.rwth-aachen.de/jupyter/clients/ipython/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax>=0.4.13->equinox) (3.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# option to disable preallocation. Otherwise Jax will commit 90% of VRAM (GPU) 
# %env XLA_PYTHON_CLIENT_PREALLOCATE=false
# Out:
# env: XLA_PYTHON_CLIENT_PREALLOCATE=false

# %%
import matplotlib.pyplot as plt

import jax.numpy as jnp
from jax.scipy.stats import norm
from jax import grad, jit, vmap
from jax import random
import jax

from jax import config
config.update("jax_enable_x64", True)

from typing import Sequence, Tuple, Union, Callable, Literal
from jaxtyping import Array, Float, Int, PyTree

import equinox as eqx
import optax
import chex

# we use tf with tfds for loading the data
import tensorflow as tf
# Ensure TF does not see GPU and grab all GPU memory.
# Note: The warnings from tf can safely be ignored.
tf.config.set_visible_devices([], device_type='GPU')

import tensorflow_datasets as tfds

from dataclasses import dataclass, astuple
from functools import partial

import numpy as np

# check for nans etc.
jax.enable_checks = True

# %%
# check if jax recognizes the GPU
jax.devices()
# Out:
# [cuda(id=0)]

# %%
# list requirements of latest run
print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# jax==0.4.20
# equinox==0.11.1
# optax==0.1.7
# chex==0.1.83
# tensorflow==2.14.0
# tensorflow_datasets==4.9.3
# numpy==1.24.4

# %%
# optional style change for print-ready figures
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": "EB Garamond",
    "font.size": 20
})

# %%
# global settings

NUM_EPOCHS = 100
BATCH_SIZE = 512
BUFFER_SIZE = 1024
LEARNING_RATE = 0.01
N_TRAINING_SAMPLES = 8 * 1024
N_TEST_SAMPLES = 4096
SEED = 42

# %%
# helper functions

@eqx.filter_jit
def value_and_jacrev(f, x):
    # Function that computes both the values and the Jacobian using reverse mode autodiff
    y, vjpfun = jax.vjp(f, x)  # Compute the values and obtain a VJP function
    basis = jnp.eye(y.size, dtype=y.dtype)
    jac = vmap(vjpfun)(basis)[0]  # Compute the Jacobian using the VJP function
    return y, jac, vjpfun

@eqx.filter_jit
def value_and_jacobian(f, x):
    y, jac, _ = value_and_jacrev(f, x)
    return y, jac

# %%
def mse(y: Float[Array, "n"], pred_y: Float[Array, "n"]) -> Float:
    return jnp.mean((y - pred_y) ** 2)

# %%
def rmse(y: Float[Array, "n"], pred_y: Float[Array, "n"]) -> Float:
    return jnp.sqrt(mse(y, pred_y))

# %% [markdown]
# # Smoothing

# %%
def sigmoidal_smoothing(f1: Callable, f2: Callable, p=0.0, w=0.005):
    """
    Smoothly transition between two functions using sigmoidal smoothing.

    Args:
        f1 (callable): The first function, f1(x), where x is a real number.
        f2 (callable): The second function, f2(x), where x is a real number.
        p (float, optional): The position to transition between the two functions. Default is 0.0.
        w (float, optional): The width of the smoothing. Default is 0.005.

    Returns:
        callable: A function that smoothly transitions between f1 and f2 at point p.

    Example:
        zero_fn = lambda x: jnp.zeros_like(x)
        id_fn   = lambda x: x
        smooth_fn = sigmoidal_smoothing(zero_fn, id_fn, p=1.0, w=0.01)
        result = smooth_fn(0.5)
    """

    def sigma(x):
        """
        Sigmoid function for smoothing.

        Args:
            x (float): The input value.

        Returns:
            float: The result of the sigmoid function.
        """
        return 1.0 / (1.0 + jnp.exp(-(x-p)/w))

    def smooth_f(x):
        """
        Smoothed function.

        Args:
            x (float): The input value.

        Returns:
            float: The result of the smoothed function.
        """
        return (1 - sigma(x)) * f1(x) + sigma(x) * f2(x)

    return smooth_f

# %%
smooth_relu = sigmoidal_smoothing(lambda x: jnp.zeros_like(x), lambda x: x)
wide_smooth_relu = lambda w: sigmoidal_smoothing(lambda x: jnp.zeros_like(x), lambda x: x, w=w)

# %%
xs = jnp.linspace(-3e-0, 3e-0, 10000)
ys = smooth_relu(xs)
ys_wide = wide_smooth_relu(w=1.0)(xs)
ys_silu = jax.nn.silu(xs)
ys_softplus = jax.nn.softplus(xs)
dys = jax.vmap(jax.grad(smooth_relu))(xs)
ddys = jax.vmap(jax.hessian(smooth_relu))(xs)


plt.title("Smoothing of max function")
plt.plot(xs, ys, '.', markersize=1.0, label="values")
plt.plot(xs, ys_wide, '.', markersize=1.0, label="wide smoothing")
plt.plot(xs, ys_silu, '.', markersize=1.0, label="silu")
plt.plot(xs, ys_softplus, '.', markersize=1.0, label="softplus")
# plt.plot(xs, dys, '.', markersize=1.0, label="1st")
# plt.plot(xs, ddys, '.', markersize=1.0, label="2nd")
plt.ylim([-1.1, 1.2])
plt.legend()
plt.show()

# %%
# Example visualizaiton of smoothed payoff and its (second-order) derivative
K = 4

def dummy_payoff(xs, K=4):
    return jnp.maximum(0, xs - K)

smoothed_dummy_payoff = lambda x, K=4: smooth_relu(x - K)
dummy_payoff = smoothed_dummy_payoff

seed = 42
n = N_TRAINING_SAMPLES
key = random.PRNGKey(seed)
key, subkey = random.split(key)
xs = random.uniform(subkey, shape=(n,), minval=1.0, maxval=10.0)
ys = dummy_payoff(xs)

# AD
dpayoff = grad(dummy_payoff)
dys = vmap(dpayoff)(xs)
ddys = vmap(grad(dpayoff))(xs)

Z_jacobian = jax.vmap(jax.jacobian(dummy_payoff))(xs)
assert(jnp.allclose(dys, Z_jacobian))
W_hessian = jax.vmap(jax.hessian(dummy_payoff))(xs)
assert(jnp.allclose(ddys, W_hessian))

Y_vjp, vjpfun = jax.vjp(dummy_payoff, xs)
basis = jnp.eye(Y_vjp.size, dtype=Y_vjp.dtype)
Z_vjp_full = vmap(vjpfun)(basis)[0]  # Compute the Jacobian using the VJP function
W_hvp = jax.jvp(jax.vmap(jax.grad(dummy_payoff)), (xs, ), (jnp.ones_like(xs), ))[1]

# FD over AD
h = 0.1
fd_xph = vmap(dpayoff)(xs + h)
fd_xmh = vmap(dpayoff)(xs - h)
ddys_fd = (fd_xph - fd_xmh) / (2 * h)

fig, axs = plt.subplots(1, 3, figsize=(12, 6))

# First plot
axs[0].set_title("Dummy Payoffs with AD")
axs[0].plot(xs, ys, '.', markersize=1, label='values')
axs[0].plot(xs, dys, '.', markersize=1, label='1st-order d')
axs[0].set_xlim([K-1, K+1])
axs[0].set_ylim([-.1, 1.2])
axs[0].legend()

# Second plot
axs[1].set_title("Dummy Payoffs with AD")
axs[1].plot(xs, ddys_fd, '.', markersize=1, label='2nd-order fd d')
axs[1].plot(xs, ddys, '.', markersize=5, label='2nd-order d')
axs[1].plot(xs, W_hessian, '.', markersize=3, label='W_hessian')
axs[1].plot(xs, W_hvp, '.', markersize=2, label='W_hvp')
axs[1].set_xlim([K-1.5e-1, K+1.5e-1])
axs[1].legend()

# FD
h = 0.1
fd_xph = dummy_payoff(xs + h)
fd_xmh = dummy_payoff(xs - h)
fd = (fd_xph - fd_xmh) / (2 * h)
fdd = (fd_xph - 2 * ys + fd_xmh) / (2 * h)

# Third plot
axs[2].set_title("Dummy Payoffs with FD")
axs[2].plot(xs, fd, '.', markersize=1, label='1st-order d')
axs[2].plot(xs, fdd, '.', markersize=2, label='2nd-order d')
axs[2].legend()

plt.show()

# %% [markdown]
# # Bachelier Dataset

# %% [markdown]
# ## Analytic solution

# %%
# Initial Bachelier code was adapted from Huge & Savine, 2020, Differential Machine Learing

# analytic solutions
def bachPrice(spot, strike, vol, T):
    d = (spot - strike) / vol / jnp.sqrt(T)
    return  vol * jnp.sqrt(T) * (d * norm.cdf(d) + norm.pdf(d))

def bachDelta(spot, strike, vol, T):
    d = (spot - strike) / vol / jnp.sqrt(T)
    return norm.cdf(d)

def bachVega(spot, strike, vol, T):
    d = (spot - strike) / vol / jnp.sqrt(T)
    return jnp.sqrt(T) * norm.pdf(d)

def bachGamma(spot, strike, vol, T):
    d = (spot - strike) / vol / jnp.sqrt(T)
    return norm.pdf(d) / (vol * jnp.sqrt(T))

def analytic_grad(X, inc1, a, K, anti=False):
    S2 = X + inc1
    bkt2 = jnp.dot(S2, a)
    pay = jnp.maximum(0, bkt2 - K)

    if anti: # two antithetic paths
        S2a = X - inc1
        bkt2a = jnp.dot(S2a, a)
        paya = jnp.maximum(0, bkt2a - K)
        
        # differentials
        Z1 =  jnp.where(bkt2 > K, 1.0, 0.0).reshape((-1,1)) * a.reshape((1,-1))
        Z2 =  jnp.where(bkt2a > K, 1.0, 0.0).reshape((-1,1)) * a.reshape((1,-1))
        Z_analytic = 0.5 * (Z1 + Z2)
                
    else: # standard 
        Z_analytic = jnp.where(bkt2 > K, 1.0, 0.0).reshape((-1,1)) * a.reshape((1,-1))
        jax.debug.print("analytic {}", jnp.where(bkt2 > K, 1.0, 0.0).reshape((-1,1)).shape)
        jax.debug.print("weights {}",  a.reshape((1,-1)).shape)
        jax.debug.print("z_analytic {}", Z_analytic.shape)

    return Z_analytic

# %% [markdown]
# ## Training data generator

# %%
@dataclass(eq=True, frozen=True)
class BachelierParams:
    n_dim: int = 1
    T1: float = 1.0
    T2: float = 2.0
    K: float = 1.10
    test_set_lb = 0.5
    test_set_ub = 1.50
    volMult: float = 1.5
    bktVol: float = 0.2
    anti: bool = False

class TrainingSet(eqx.Module):
    X: Array 
    Y: Array
    Z: Array
    W: Array
    weights: Array
    inc1: Array
    Z_fd: Array
    W_fd_of_fd: Array
    W_fd_of_vjp: Array
    W_fd_of_grad: Array

    def shapes(self):
        jax.debug.print("X {X}, Y {Y}, Z {Z}, W {W}", X=X.shape, Y=Y.shape, Z=Z.shape, W=W.shape)

class TestSet(eqx.Module):
    spots: Array
    baskets: Array
    prices: Array
    deltas: Array
    vegas: Array
    gammas: Array


def payoff_fn(X, inc1, a, K, anti=False):
    S2 = X + inc1
    bkt2 = jnp.dot(S2, a)
    pay = smooth_relu(bkt2 - K)
    
    if anti: # two antithetic paths
        S2a = X - inc1
        bkt2a = jnp.dot(S2a, a)
        paya = smooth_relu(bkt2a - K)
        Y = 0.5 * (pay + paya)
    else: # standard
        Y = pay

    return Y
    
# generate a random correlation matrix
def genCorrel(key, n):
    randoms = random.uniform(key, shape=(2*n, n), minval=-1., maxval=1.)
    cov = randoms.T @ randoms
    invvols = jnp.diag(1. / jnp.sqrt(jnp.diagonal(cov)))
    return jnp.linalg.multi_dot([invvols, cov, invvols])

# training set: returns S1 (mxn), C2 (mx1) and dC2/dS1 (mxn)
@partial(jit, static_argnums=(0,1,2,3))
def trainingSet(m: int, params: BachelierParams, seed=2, bktVol=0.2) -> TrainingSet:
    n = params.n_dim
    T1 = params.T1
    T2 = params.T2
    K = params.K
    volMult = params.volMult

    key = random.PRNGKey(seed)

    # spots all currently 1, without loss of generality
    S0 = jnp.repeat(1., n)
    # random correl
    key, subkey = random.split(key)
    corr = genCorrel(subkey, n)
    jax.debug.print("corr is {}", corr)
    # random weights
    key, subkey = random.split(key)
    a = random.uniform(subkey, shape=(n,), minval=1., maxval=10.)
    a /= jnp.sum(a)
    jax.debug.print("basket asset weights are {}", a)
    # random vols
    key, subkey = random.split(key)
    vols = random.uniform(subkey, shape=(n,), minval=5., maxval=50.)
    jax.debug.print("vols is {}", vols.shape)
    # normalize vols for a given volatility of basket, 
    # helps with charts without loss of generality
    avols = (a * vols).reshape((-1,1))
    jax.debug.print("avols is {}", avols.shape)
    v = jnp.sqrt(jnp.linalg.multi_dot([avols.T, corr, avols]).reshape(1))
    jax.debug.print("v.shape is {}", v.shape)
    vols = vols * bktVol / v
    bktVol = bktVol
    jax.debug.print("bkt vol is= {v}", v=bktVol)

    # Choleski etc. for simulation
    diagv = jnp.diag(vols)
    jax.debug.print("diagv {}", diagv.shape)
    cov = jnp.linalg.multi_dot([diagv, corr, diagv])
    jax.debug.print("cov {}", cov.shape)
    chol = jnp.linalg.cholesky(cov) * jnp.sqrt(T2 - T1)
    # increase vols for simulation of X so we have more samples in the wings
    chol0 = chol * volMult * jnp.sqrt(T1 / (T2 - T1))
    # simulations
    key, subkey = random.split(key)
    normals = random.normal(subkey, shape=(2, m, n))

    jax.debug.print("normals 0 is {}", normals[0, :, :].shape)
    jax.debug.print("chol0 is {}", chol0.T.shape)
    inc0 = normals[0, :, :] @ chol0.T

    jax.debug.print("inc0.shape is {}", inc0.shape)
    
    inc1 = normals[1, :, :] @ chol.T

    S1 = S0 + inc0

      
    payoff = partial(payoff_fn, a=a, K=K, anti=params.anti)

    Z_analytic = analytic_grad(S1, inc1, a, K, anti=params.anti)
    # Compute the values and obtain a VJP function
    Y_vjp, vjpfun = jax.vjp(payoff, S1, inc1)
    Z_vjp = vjpfun(jnp.ones(Y_vjp.size))[0]
    
    # if not independent, we need to use the commented out section instead
    basis = jnp.eye(Y_vjp.size, dtype=Y_vjp.dtype)
    Z_vjp_full = vmap(vjpfun)(basis)[0]  # Compute the Jacobian using the VJP function

    # using first order finite differences
    h = 1e-4
    fd_ph = payoff(S1 + h, inc1)
    fd_mh = payoff(S1 - h, inc1)
    Z_fd = (fd_ph - fd_mh) / (2 * h)

    # using second order finite differences
    h = 1e-2
    fdd = (fd_ph - 2 * Y_vjp + fd_mh) / (h * h)
    W_fd_of_fd = fdd[..., jnp.newaxis]

    # using first order finite difference over vjp
    h = 1e-4
    fd_of_vjp_ph = vjpfun(jnp.ones(Y_vjp.size) + h)[0]
    fd_of_vjp_mh  = vjpfun(jnp.ones(Y_vjp.size) - h)[0]
    W_fd_of_vjp = (fd_of_vjp_ph - fd_of_vjp_mh) / (2 * h)

    Dpayoff = vmap(jax.grad(payoff))
    W_fd_of_grad_ph = Dpayoff(S1 + h, inc1)
    W_fd_of_grad_mh = Dpayoff(S1 - h, inc1)
    W_fd_of_grad = (W_fd_of_grad_ph - W_fd_of_grad_mh) / (2 * h)

    Y, Z_grad = jax.vmap(jax.value_and_grad(payoff, argnums=0))(S1, inc1)

    jax.debug.print("Example values: {val1}, {val2}", val1=Z_grad[2,0], val2=Z_vjp[2,0])
    jax.debug.print("MSE(W_fd_of_fd, W_fd_of_vjp): {mse}", mse=mse(W_fd_of_fd, W_fd_of_vjp))
    jax.debug.print("MSE(Z_grad, Z_analytic) = {res}", res=mse(Z_grad, Z_analytic))
    jax.debug.print("MSE(Z_vjp, Z_analytic) = {res}", res=mse(Z_vjp, Z_analytic))
    jax.debug.print("MSE(Y_vjp, Y) = {res}", res=mse(Y_vjp, Y))
    jax.debug.print("Close(Y_vjp, Y) ? {res}", res=jnp.allclose(Y_vjp, Y))
    jax.debug.print("Close(Z_vjp, Z) ? {res}", res=jnp.allclose(Z_vjp, Z_analytic, rtol=1e-4, atol=1e-0))
    jax.debug.print("Close(Z_grad, Z) ? {res}", res=jnp.allclose(Z_grad, Z_analytic, rtol=1e-4, atol=1e-0))

    W_hessian = jax.vmap(jax.hessian(payoff, argnums=0))(S1, inc1)
    
    X = S1
    return TrainingSet(X, Y_vjp.reshape(-1,1), Z_vjp, W_hessian, a, inc1, Z_fd, W_fd_of_fd, W_fd_of_vjp, W_fd_of_grad)

# %% [markdown]
# ## Test data generator

# %%
def testSet(params: BachelierParams, training_set: TrainingSet, n_samples:int=4096, seed:int=42) -> TestSet:
    # test set: returns an array of independent, uniformly random spots 
    # with corresponding baskets, ground true prices, deltas and vegas

    n = params.n_dim
    K = params.K
    bktVol = params.bktVol
    T1 = params.T1
    T2 = params.T2
    lower = params.test_set_lb
    upper = params.test_set_ub
    weights = training_set.weights
    
    key = random.PRNGKey(seed)
    # adjust lower and upper for dimension
    adj = 1 + 0.5 * jnp.sqrt((n-1)*(upper-lower)/12)
    adj_lower = 1.0 - (1.0-lower) * adj
    adj_upper = 1.0 + (upper - 1.0) * adj
    # draw spots
    key, subkey = random.split(key)
    spots = random.uniform(subkey, shape=(n_samples, n), minval=adj_lower, maxval=adj_upper)
    # compute baskets, prices, deltas and vegas
    baskets = jnp.dot(spots, weights).reshape((-1, 1))
    prices = bachPrice(baskets, K, bktVol, T2 - T1).reshape((-1, 1))
    deltas = bachDelta(baskets, K, bktVol, T2 - T1) @ weights.reshape((1, -1))
    vegas = bachVega(baskets, K, bktVol, T2 - T1)
    gammas = bachGamma(baskets, K, bktVol, T2 - T1)
    return TestSet(spots, baskets, prices, deltas, vegas, gammas)

# %% [markdown]
# ## Data generation

# %% [markdown]
# ### 1D for visualization

# %%
bachelier_params = BachelierParams(n_dim=1, anti=True)
training_set = trainingSet(N_TRAINING_SAMPLES, bachelier_params, seed=42)
X, Y, Z, W, weights, inc1, Z_fd, W_fd_of_fd, W_fd_of_vjp, W_fd_of_grad = astuple(training_set)

test_set = testSet(bachelier_params, training_set, n_samples=10 * N_TEST_SAMPLES)
spots, baskets, prices, deltas, vegas, gammas = astuple(test_set)
# Out:
# inc0.shape is (array(8192), array(1))
# chol0 is (array(1), array(1))
# normals 0 is (array(8192), array(1))
# cov (array(1), array(1))
# diagv (array(1), array(1))
# bkt vol is= 0.2
# v.shape is (array(1),)
# avols is (array(1), array(1))
# vols is (array(1),)
# basket asset weights are [1.]
# corr is [[1.]]
# Example values: 1.0, 1.0
# MSE(W_fd_of_fd, W_fd_of_vjp): 0.30469131302001895
# Close(Z_vjp, Z) ? True
# Close(Z_grad, Z) ? True
# MSE(Z_grad, Z_analytic) = 0.0005660154384085881
# MSE(Z_vjp, Z_analytic) = 0.0005660154384085881
# MSE(Y_vjp, Y) = 0.0
# Close(Y_vjp, Y) ? True

# %% [markdown]
# #### Plot generated Data

# %%
def plot_payoff_data(axs, x_train, y_train, x_test, y_test):
    axs.set_title("Payoff Data")
    axs.plot(x_train, y_train, '.', label='Payoff Training', markersize=1)
    axs.plot(x_test, y_test, '.', label='Payoff Test', markersize=1)
    axs.legend()

def plot_delta_data(axs, x_train, x_test, dydx_train, dydx_test):
    axs.set_title("Delta Data")
    axs.plot(x_train, dydx_train, '.', label='Delta Training', markersize=1)
    axs.plot(x_test, dydx_test, '.', label='Delta Test', markersize=1)
    axs.legend()

# %%
fig, axs = plt.subplots(4, 2)

Xs = X

plot_payoff_data(axs[0, 1], Xs, Y[:,0], baskets[:, 0], prices[:,0])
plot_delta_data(axs[0, 0], Xs, baskets[:, 0], Z[:,0], deltas[:,0])

axs[1, 0].set_title("Finite Difference Deltas")
axs[1, 0].plot(Xs, Z_fd, '.', label='FD', markersize=1)
axs[1, 1].set_title("Second-Order Finite Difference Gammas")
axs[1, 1].plot(Xs, W_fd_of_fd, '.', label='FD', markersize=1)

axs[2, 0].set_title("First-Order FD over VJP Gammas")
axs[2, 0].plot(Xs, W_fd_of_vjp, ".", label='FD', markersize=1)
axs[2, 1].set_title("First-Order FD over Grad")
axs[2, 1].plot(Xs, W_fd_of_grad, ".", label='FD', markersize=1)

axs[3, 0].set_title("First-Order JVP")
axs[3,0].plot(Xs, Z, ".", markersize=1)
axs[3, 1].set_title("Second-Order via Hessian")
axs[3,1].plot(Xs, W[:, 0, 0], ".", markersize=1)

# Adjust the spacing between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7D for training

# %%
use_anti = True
bachelier_params = BachelierParams(n_dim=100, anti=use_anti)
training_set = trainingSet(N_TRAINING_SAMPLES, bachelier_params, seed=42)
X, Y, Z, W, weights, inc1, fd, fdd, jac_fd, fdd_over_grad = astuple(training_set)
test_set = testSet(bachelier_params, training_set, n_samples=N_TEST_SAMPLES)
spots, baskets, prices, deltas, vegas, gammas = astuple(test_set)
payoff = partial(payoff_fn, a=weights, K=bachelier_params.K, anti=use_anti)
D_payoff = vmap(grad(payoff))
# Out:
# bkt vol is= 0.2
# inc0.shape is (array(8192), array(100))
# chol0 is (array(100), array(100))
# normals 0 is (array(8192), array(100))
# cov (array(100), array(100))
# diagv (array(100), array(100))
# v.shape is (array(1),)
# avols is (array(100), array(1))
# vols is (array(100),)
# basket asset weights are [0.00842796 0.00473911 0.01696552 0.00374883 0.0050188  0.00976018
#  0.00786359 0.00567595 0.01369407 0.00300226 0.00340391 0.01714405
#  0.01378316 0.01437387 0.00897909 0.01114411 0.01716918 0.00219924
#  0.01843901 0.00270186 0.01349464 0.00791583 0.01748267 0.00801769
#  0.00499796 0.00656943 0.00482812 0.01156914 0.01424641 0.01587831
#  0.0118096  0.0092067  0.00975259 0.01175582 0.00517958 0.00884431
#  0.01659577 0.00913674 0.01729864 0.01512967 0.01195507 0.00430765
#  0.00236872 0.00595484 0.00382429 0.01296679 0.00875904 0.00804917
#  0.00220595 0.00473235 0.01243846 0.0109028  0.0153246  0.00940062
#  0.01694642 0.00424784 0.01828212 0.00604021 0.01359456 0.00845313
#  0.01323558 0.0186169  0.01834555 0.01742432 0.00630418 0.00677747
#  0.0021237  0.00549716 0.00516831 0.00483622 0.01164315 0.01092628
#  0.01096933 0.00511699 0.00480439 0.00555139 0.01566161 0.009383
#  0.01724635 0.00509873 0.00408031 0.01448669 0.00496614 0.00768011
#  0.01058922 0.01687651 0.01811666 0.00370248 0.01284856 0.01877609
#  0.00198274 0.01794062 0.01522681 0.01775794 0.01338496 0.00691311
#  0.00305881 0.01170953 0.01139198 0.00508214]
# corr is [[ 1.         -0.02137867 -0.00515323 ... -0.05988151  0.01912844
#    0.05531181]
#  [-0.02137867  1.         -0.00689527 ...  0.0095235   0.04573215
#   -0.0435215 ]
#  [-0.00515323 -0.00689527  1.         ...  0.0539933  -0.02829928
#    0.03481056]
#  ...
#  [-0.05988151  0.0095235   0.0539933  ...  1.         -0.14888839
#   -0.17204541]
#  [ 0.01912844  0.04573215 -0.02829928 ... -0.14888839  1.
#   -0.07050866]
#  [ 0.05531181 -0.0435215   0.03481056 ... -0.17204541 -0.07050866
#    1.        ]]
# MSE(Y_vjp, Y) = 0.0
# Close(Y_vjp, Y) ? True
# Example values: -4.1782064118176427e-05, -4.1782064118176427e-05
# MSE(W_fd_of_fd, W_fd_of_vjp): 3.6563473582301835e-05
# MSE(Z_grad, Z_analytic) = 7.811457491968278e-08
# MSE(Z_vjp, Z_analytic) = 7.811457491968278e-08
# Close(Z_vjp, Z) ? True
# Close(Z_grad, Z) ? True

# %% [markdown]
# #### Plot generated Data

# %%
vis_dim = 0
fig, axs = plt.subplots(1, 2)

plot_payoff_data(axs[0], X[:,vis_dim], Y[:,vis_dim], baskets[:, vis_dim], prices[:,vis_dim])
plot_delta_data(axs[1], X[:,vis_dim], baskets[:, vis_dim], Z[:,vis_dim], deltas[:,vis_dim])

plt.show()

# %% [markdown]
# # Standard ML

# %%
@jit
def normalize(data: Array):
    mean = jnp.mean(data)
    std = jnp.std(data)
    return (data - mean) / std, mean, std

# normalize data
x_train, x_train_mean, x_train_std = normalize(X)
y_train, y_train_mean, y_train_std = normalize(Y)
dydx_train, dydx_train_mean, dydx_train_std = normalize(Z)

# %%
x_train = X
y_train = Y
dydx_train = Z

# %%
# Hyperparameters
# batch_size = 128
# learning_rate = 0.01
num_epochs = NUM_EPOCHS
seed = 42

key = jax.random.PRNGKey(seed)

# %%
def x_normalizer(x):
    return (x - x_train_mean) / x_train_std

def y_denormalizer(x):
    return x * y_train_std + y_train_mean

class MLP_Normalized(eqx.Module):
    layers: list
    in_size: Union[int, Literal["scalar"]] = eqx.field(static=True)
    out_size: Union[int, Literal["scalar"]] = eqx.field(static=True)
    
    def __init__(self, key, in_size, out_size):
        key, subkey = jax.random.split(key)
        self.layers = [x_normalizer, 
                       eqx.nn.MLP(key=subkey, in_size=in_size, out_size=out_size, width_size=20, depth=3, 
                                  activation=wide_smooth_relu(10.0)), 
                       y_denormalizer]
        self.in_size= in_size
        self.out_size= out_size

    def __call__(self, x):
        for layer in self.layers:
            x = layer(x)

        return x

# %%
def trunc_init(weight: Array, key: jax.random.PRNGKey) -> Array:
    out, in_ = weight.shape
    stddev = jnp.sqrt(1 / in_)
    return jax.nn.initializers.glorot_normal()(key, (out, in_))

def init_linear_weight(model, init_fn, key):
    is_linear = lambda x: isinstance(x, eqx.nn.Linear)
    get_weights = lambda m: [x.weight
                           for x in jax.tree_util.tree_leaves(m, is_leaf=is_linear)
                           if is_linear(x)]
    weights = get_weights(model)
    new_weights = [init_fn(weight, subkey)
                 for weight, subkey in zip(weights, jax.random.split(key, len(weights)))]
    new_model = eqx.tree_at(get_weights, model, new_weights)
    return new_model

# %%
@eqx.filter_jit
def loss_fn(model: eqx.nn.MLP, x: Float[Array, "batch"], y: Float[Array, "batch"]) -> Float:
    pred_y = vmap(model)(x)
    pred_y = pred_y[:, jnp.newaxis]
    result = mse(y, pred_y)
    return result

# %%
@eqx.filter_jit
def evaluate(model, testloader):
    """
    This function evaluates the model on the test dataset,
    computing both the average loss.
    """
    avg_loss = 0
    for (x, y, _) in testloader:
        avg_loss += loss_fn(model, x, y)
    return avg_loss / len(testloader)

# %% [markdown]
# ## Train

# %%
def train(model: eqx.nn.MLP,
          generator_train_ds,
          generator_test_ds,
          optim: optax.GradientTransformation,
          n_epochs: Int = NUM_EPOCHS
          ) -> PyTree:
    
    @eqx.filter_jit
    def train_step(model: eqx.nn.MLP,
                   opt_state: PyTree,
                   x: Float[Array, "batch"],
                   y: Float[Array, "batch"]
                   ):
        loss_value, grads = eqx.filter_value_and_grad(loss_fn)(model, x, y)
        updates, opt_state = optim.update(grads, opt_state, model)
        model = eqx.apply_updates(model, updates)
        return model, opt_state, loss_value

    opt_state = optim.init(eqx.filter(model, eqx.is_array))

    for epoch in range(n_epochs):
        for (batch_x, batch_y, _) in generator_train_ds:

            model, opt_state, train_loss = train_step(model, opt_state, batch_x, batch_y)

        test_loss = jnp.sqrt(evaluate(model, generator_test_ds))
        print('Finished epoch {:3d}'.format(epoch), 
                ' | Train Loss: {:.5f}'.format(train_loss),
                ' | Test Loss: {:.5f}'.format(test_loss))

    return model

# %%
def gen_data_standard_ml():
    train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train, dydx_train))
    
    x_test = spots
    y_test = prices
    dydx_test = deltas
    test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test, dydx_test))
    
    train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    
    generator_train_ds = tfds.as_numpy(train_dataset)
    generator_test_ds = tfds.as_numpy(test_dataset)
    return generator_train_ds, generator_test_ds, x_test

# %%
def bachelier_train_standard_ml(key: Array):
    key, subkey = jax.random.split(key)
    model = MLP_Normalized(key, in_size=x_train.shape[1], out_size="scalar")
    
    key, subkey = jax.random.split(key)
    model = init_linear_weight(model, trunc_init, key)
    
    # use linear on-cycle decay scheduler
    num_epochs = 100
    total_steps = num_epochs * (len(x_train) // BATCH_SIZE) + num_epochs
    # print(total_steps)
    # lr_schedule = optax.linear_onecycle_schedule(transition_steps=total_steps, peak_value=0.1,
    #                                                                  pct_start=0.2, pct_final=0.6,
    #                                                                  div_factor=1000., final_div_factor=1.0e4)
    
    
    lr_schedule = optax.exponential_decay(init_value=0.001, transition_steps=total_steps, transition_begin=int(total_steps*0.2), decay_rate=0.9)
    
    # lr_schedule = optax.cosine_onecycle_schedule(transition_steps=total_steps, peak_value=0.01)
    # lr_schedule = optax.constant_schedule(0.0001)
    # lr_schedule = optax.cosine_decay_schedule(init_value=0.01, decay_steps=total_steps)
    
    # optim = optax.adam(learning_rate=0.001)
    # optim = optax.adam(learning_rate=lr_schedule)
    optim = optax.adam(learning_rate=lr_schedule)
    model = train(model, generator_train_ds, generator_test_ds, optim, n_epochs=num_epochs)
    return model

# %%
generator_train_ds, generator_test_ds, x_test = gen_data_standard_ml()
key = jax.random.PRNGKey(42)
model_ml = bachelier_train_standard_ml(key)
# Out:
# Finished epoch   0  | Train Loss: 0.01516  | Test Loss: 0.04684
# Finished epoch   1  | Train Loss: 0.01304  | Test Loss: 0.05498
# Finished epoch   2  | Train Loss: 0.00782  | Test Loss: 0.05182
# Finished epoch   3  | Train Loss: 0.00718  | Test Loss: 0.04567
# Finished epoch   4  | Train Loss: 0.00581  | Test Loss: 0.04467
# Finished epoch   5  | Train Loss: 0.00511  | Test Loss: 0.04342
# Finished epoch   6  | Train Loss: 0.00561  | Test Loss: 0.04168
# Finished epoch   7  | Train Loss: 0.00521  | Test Loss: 0.04003
# Finished epoch   8  | Train Loss: 0.00565  | Test Loss: 0.03861
# Finished epoch   9  | Train Loss: 0.00458  | Test Loss: 0.03682
# Finished epoch  10  | Train Loss: 0.00421  | Test Loss: 0.03375
# Finished epoch  11  | Train Loss: 0.00394  | Test Loss: 0.02963
# Finished epoch  12  | Train Loss: 0.00302  | Test Loss: 0.02323
# Finished epoch  13  | Train Loss: 0.00283  | Test Loss: 0.01573
# Finished epoch  14  | Train Loss: 0.00222  | Test Loss: 0.01081
# Finished epoch  15  | Train Loss: 0.00200  | Test Loss: 0.00946
# Finished epoch  16  | Train Loss: 0.00203  | Test Loss: 0.00881
# Finished epoch  17  | Train Loss: 0.00186  | Test Loss: 0.00809
# Finished epoch  18  | Train Loss: 0.00192  | Test Loss: 0.00797
# Finished epoch  19  | Train Loss: 0.00179  | Test Loss: 0.00746
# Finished epoch  20  | Train Loss: 0.00184  | Test Loss: 0.00728
# Finished epoch  21  | Train Loss: 0.00197  | Test Loss: 0.00687
# Finished epoch  22  | Train Loss: 0.00183  | Test Loss: 0.00671
# Finished epoch  23  | Train Loss: 0.00179  | Test Loss: 0.00671
# Finished epoch  24  | Train Loss: 0.00156  | Test Loss: 0.00639
# Finished epoch  25  | Train Loss: 0.00174  | Test Loss: 0.00635
# Finished epoch  26  | Train Loss: 0.00170  | Test Loss: 0.00637
# Finished epoch  27  | Train Loss: 0.00166  | Test Loss: 0.00634
# Finished epoch  28  | Train Loss: 0.00185  | Test Loss: 0.00623
# Finished epoch  29  | Train Loss: 0.00193  | Test Loss: 0.00615
# Finished epoch  30  | Train Loss: 0.00188  | Test Loss: 0.00617
# Finished epoch  31  | Train Loss: 0.00193  | Test Loss: 0.00625
# Finished epoch  32  | Train Loss: 0.00159  | Test Loss: 0.00596
# Finished epoch  33  | Train Loss: 0.00158  | Test Loss: 0.00599
# Finished epoch  34  | Train Loss: 0.00168  | Test Loss: 0.00617
# Finished epoch  35  | Train Loss: 0.00160  | Test Loss: 0.00613
# Finished epoch  36  | Train Loss: 0.00169  | Test Loss: 0.00604
# Finished epoch  37  | Train Loss: 0.00187  | Test Loss: 0.00600
# Finished epoch  38  | Train Loss: 0.00161  | Test Loss: 0.00592
# Finished epoch  39  | Train Loss: 0.00150  | Test Loss: 0.00613
# Finished epoch  40  | Train Loss: 0.00161  | Test Loss: 0.00604
# Finished epoch  41  | Train Loss: 0.00153  | Test Loss: 0.00617
# Finished epoch  42  | Train Loss: 0.00167  | Test Loss: 0.00601
# Finished epoch  43  | Train Loss: 0.00143  | Test Loss: 0.00602
# Finished epoch  44  | Train Loss: 0.00188  | Test Loss: 0.00587
# Finished epoch  45  | Train Loss: 0.00144  | Test Loss: 0.00591
# Finished epoch  46  | Train Loss: 0.00197  | Test Loss: 0.00578
# Finished epoch  47  | Train Loss: 0.00159  | Test Loss: 0.00606
# Finished epoch  48  | Train Loss: 0.00113  | Test Loss: 0.00605
# Finished epoch  49  | Train Loss: 0.00183  | Test Loss: 0.00610
# Finished epoch  50  | Train Loss: 0.00152  | Test Loss: 0.00624
# Finished epoch  51  | Train Loss: 0.00186  | Test Loss: 0.00582
# Finished epoch  52  | Train Loss: 0.00146  | Test Loss: 0.00613
# Finished epoch  53  | Train Loss: 0.00155  | Test Loss: 0.00639
# Finished epoch  54  | Train Loss: 0.00158  | Test Loss: 0.00624
# Finished epoch  55  | Train Loss: 0.00151  | Test Loss: 0.00625
# Finished epoch  56  | Train Loss: 0.00160  | Test Loss: 0.00634
# Finished epoch  57  | Train Loss: 0.00142  | Test Loss: 0.00630
# Finished epoch  58  | Train Loss: 0.00150  | Test Loss: 0.00645
# Finished epoch  59  | Train Loss: 0.00140  | Test Loss: 0.00643
# Finished epoch  60  | Train Loss: 0.00181  | Test Loss: 0.00640
# Finished epoch  61  | Train Loss: 0.00146  | Test Loss: 0.00640
# Finished epoch  62  | Train Loss: 0.00179  | Test Loss: 0.00621
# Finished epoch  63  | Train Loss: 0.00169  | Test Loss: 0.00649
# Finished epoch  64  | Train Loss: 0.00160  | Test Loss: 0.00608
# Finished epoch  65  | Train Loss: 0.00136  | Test Loss: 0.00611
# Finished epoch  66  | Train Loss: 0.00186  | Test Loss: 0.00635
# Finished epoch  67  | Train Loss: 0.00151  | Test Loss: 0.00612
# Finished epoch  68  | Train Loss: 0.00135  | Test Loss: 0.00660
# Finished epoch  69  | Train Loss: 0.00153  | Test Loss: 0.00640
# Finished epoch  70  | Train Loss: 0.00147  | Test Loss: 0.00665
# Finished epoch  71  | Train Loss: 0.00153  | Test Loss: 0.00654
# Finished epoch  72  | Train Loss: 0.00180  | Test Loss: 0.00658
# Finished epoch  73  | Train Loss: 0.00160  | Test Loss: 0.00676
# Finished epoch  74  | Train Loss: 0.00149  | Test Loss: 0.00635
# Finished epoch  75  | Train Loss: 0.00159  | Test Loss: 0.00619
# Finished epoch  76  | Train Loss: 0.00154  | Test Loss: 0.00667
# Finished epoch  77  | Train Loss: 0.00165  | Test Loss: 0.00687
# Finished epoch  78  | Train Loss: 0.00135  | Test Loss: 0.00664
# Finished epoch  79  | Train Loss: 0.00148  | Test Loss: 0.00642
# Finished epoch  80  | Train Loss: 0.00147  | Test Loss: 0.00661
# Finished epoch  81  | Train Loss: 0.00148  | Test Loss: 0.00649
# Finished epoch  82  | Train Loss: 0.00153  | Test Loss: 0.00676
# Finished epoch  83  | Train Loss: 0.00170  | Test Loss: 0.00681
# Finished epoch  84  | Train Loss: 0.00165  | Test Loss: 0.00660
# Finished epoch  85  | Train Loss: 0.00115  | Test Loss: 0.00690
# Finished epoch  86  | Train Loss: 0.00153  | Test Loss: 0.00657
# Finished epoch  87  | Train Loss: 0.00159  | Test Loss: 0.00635
# Finished epoch  88  | Train Loss: 0.00122  | Test Loss: 0.00681
# Finished epoch  89  | Train Loss: 0.00157  | Test Loss: 0.00641
# Finished epoch  90  | Train Loss: 0.00143  | Test Loss: 0.00666
# Finished epoch  91  | Train Loss: 0.00149  | Test Loss: 0.00708
# Finished epoch  92  | Train Loss: 0.00172  | Test Loss: 0.00670
# Finished epoch  93  | Train Loss: 0.00129  | Test Loss: 0.00670
# Finished epoch  94  | Train Loss: 0.00164  | Test Loss: 0.00698
# Finished epoch  95  | Train Loss: 0.00162  | Test Loss: 0.00676
# Finished epoch  96  | Train Loss: 0.00166  | Test Loss: 0.00644
# Finished epoch  97  | Train Loss: 0.00160  | Test Loss: 0.00725
# Finished epoch  98  | Train Loss: 0.00159  | Test Loss: 0.00675
# Finished epoch  99  | Train Loss: 0.00145  | Test Loss: 0.00669

# %%
class Predictions(eqx.Module):
    y: Array
    dydx: Array
    ddyddx: Array

@eqx.filter_jit
def predict(model, xs):
    pred_y, pred_dydx = vmap(eqx.filter_value_and_grad(model))(xs)
    pred_ddyddx = vmap(jax.hessian(model))(xs)

    return Predictions(pred_y, pred_dydx, pred_ddyddx)

# %%
pred = predict(model_ml, x_test)

# %%
@eqx.filter_jit
def eval(pred: Predictions, test_set: TestSet):
    x_test, baskets, y_test, dydx_test, vegas, gammas = astuple(test_set)
    pred_y, pred_dydx, pred_ddyddx = astuple(pred)
    pred_y = pred_y[:, jnp.newaxis]
    pred_gammas = jnp.sum(pred.ddyddx, axis=(1, 2))

    rmse_y = rmse(pred_y, y_test)
    rmse_dydx = rmse(pred_dydx, dydx_test)
    rmse_ddyddx = rmse(pred_gammas, gammas)
    
    return rmse_y, rmse_dydx, rmse_ddyddx

# %% [markdown]
# ## Plot results

# %% [markdown]
# ### For notebook

# %%
import datetime

def plot_eval(model, pred: Predictions, test_set: TestSet, method: str):

    def print_rmse(pred, true):
        plt.title(f"RMSE: {rmse(true, pred)}")

    x_test, baskets, y_test, dydx_test, vegas, gammas = astuple(test_set)
    pred_y, pred_dydx, pred_ddyddx = astuple(pred)
    pred_y = pred_y[:, jnp.newaxis]

    # Create a single figure with 3 subplots
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    # Plot the first subplot
    axes[0].plot(baskets, pred_y, '.', markersize=1)
    axes[0].plot(baskets, y_test, '.', markersize=1)
    axes[0].legend(['Pred Price', 'True Price'], loc='upper left')
    axes[0].set_title(f"Values \n {rmse(pred_y, y_test)}")

    # Plot the second subplot
    dydx_idx = 0
    axes[1].plot(baskets, pred_dydx[:, dydx_idx], '.', markersize=1)
    axes[1].plot(baskets, dydx_test[:, dydx_idx], '.', markersize=1)
    axes[1].legend(['Pred Delta', 'True Delta'], loc='upper left')
    axes[1].set_title(f"Differentials\n{rmse(pred_dydx, dydx_test)}")

    # Calculate and plot gammas in the third subplot
    pred_gammas = jnp.sum(pred_ddyddx, axis=(1, 2))
    axes[2].plot(baskets, pred_gammas, '.', markersize=1, label='Pred')
    axes[2].plot(baskets, gammas, '.', markersize=1, label='True')
    axes[2].legend()
    axes[2].set_title(f"Gammas\n{rmse(pred_gammas, gammas)}")

    # Adjust the layout and save the figure to a PDF file
    plt.tight_layout()
    plt.show()
    now = datetime.datetime.now()
    fig.savefig(f'results/all_at_once/eval_ml_{now}.pdf', bbox_inches='tight')

plot_eval(model_ml, pred, test_set, "ml")

# %% [markdown]
# ### For latex

# %%
import datetime

BASE_PATH  = "results/single/"
VALUE_PATH = "values/"
DELTA_PATH = "deltas/"
GAMMA_PATH = "gammas/"

def plot_eval(model, pred: Predictions, test_set: TestSet, method: str, format: str = "pdf"):

    def print_rmse(pred, true):
        # plt.title(f"RMSE: {rmse(true, pred)}")
        print(f"RMSE: {rmse(true, pred)}")

    x_test, baskets, y_test, dydx_test, vegas, gammas = astuple(test_set)
    pred_y, pred_dydx, pred_ddyddx = astuple(pred)
    pred_y = pred_y[:, jnp.newaxis]

    
    fig = plt.figure()
    print_rmse(pred_y, y_test)
    # plt.suptitle("Evaluation")
    plt.plot(baskets, pred_y, '.', markersize=1)
    plt.plot(baskets, y_test, '.', markersize=1)
    # plt.ylabel(r'$V$', rotation=0)
    # plt.xlabel(r'$S_0$')
    # plt.legend(['Pred Price', 'True Price'], loc='upper left')
    plt.show()
    
    now = datetime.datetime.now()
    fig.savefig(f'{BASE_PATH}{VALUE_PATH}eval_{method}_{now}.{format}', bbox_inches='tight')

    
    fig = plt.figure()
    print_rmse(pred_dydx, dydx_test)
    # plt.suptitle("Differentials")
    dydx_idx = 0
    plt.plot(baskets, pred_dydx[:, dydx_idx], '.', markersize=1)
    plt.plot(baskets, dydx_test[:, dydx_idx], '.', markersize=1)
    # plt.ylabel(r'$\frac{\partial V}{\partial S_0}$', rotation=0)
    # plt.xlabel(r'$S_0$')
    # plt.legend(['Pred Delta', 'True Delta'], loc='upper left')
    plt.show()
    now = datetime.datetime.now()
    fig.savefig(f'{BASE_PATH}{DELTA_PATH}eval_delta_{method}_{now}.{format}', bbox_inches='tight')


    pred_gammas = jnp.sum(pred.ddyddx, axis=(1, 2))

    fig = plt.figure()
    print_rmse(pred_gammas, gammas)
    # plt.suptitle("Gammas")
    plt.plot(baskets, pred_gammas, '.', markersize=1, label='Pred')
    plt.plot(baskets, gammas, '.', markersize=1, label='True')
    # plt.ylabel(r'$\frac{\partial^2 V}{\partial S_0^2}$', rotation=0)
    # plt.xlabel(r'$S_0$')
    # plt.legend()
    plt.show()
    now = datetime.datetime.now()
    fig.savefig(f'{BASE_PATH}{GAMMA_PATH}eval_gamma_{method}_{now}.{format}', bbox_inches='tight')

# %%
plot_eval(model, pred, test_set, "standard_ml")
# Out:
# RMSE: 0.0034459942302796616
# RMSE: 0.005496625771726484
# RMSE: 0.9754670337612588

# %% [markdown]
# # Differential ML

# %% [markdown]
# ## Data generation

# %%
@eqx.filter_jit
def diff_loss_fn(model: eqx.nn.MLP, x: Float[Array, "batch"], y: Float[Array, "batch"], dydx: Float[Array, "batch"]) -> Float:
    lam = 1
    n_dims = x.shape[1]
    lambda_scale = lam * n_dims
    alpha = 1.0/(1.0 + lambda_scale)
    beta = lambda_scale/(1.0 + lambda_scale)

    # alpha = 0.5
    # beta = 1.0 - alpha
    y_pred, dydx_pred = vmap(eqx.filter_value_and_grad(model))(x)

    y_pred = y_pred[..., jnp.newaxis]
    dydx_pred = dydx_pred
    assert(y_pred.shape == y.shape)
    assert(dydx_pred.shape == dydx.shape)
    value_loss = alpha * jnp.mean((y_pred - y)**2)
    grad_loss = beta * jnp.mean((dydx_pred - dydx)**2)
    loss = value_loss + grad_loss

    # jax.debug.print('[Internal] Value Loss {value_loss} | Grad Loss: {grad_loss}', value_loss=value_loss, grad_loss=grad_loss)
    return loss

# %%
def optimal_step(x: Float):
    h = jnp.sqrt(jnp.finfo(jnp.float32).eps)
    return h * jnp.fabs(x)

# %% [markdown]
# ## Train

# %%
def diff_train(model: eqx.nn.MLP,
          generator_train_ds,
          generator_test_ds,
          optim: optax.GradientTransformation,
          n_epochs: Int = NUM_EPOCHS
          ) -> PyTree:
    
    @eqx.filter_jit
    def train_step(model: eqx.nn.MLP,
                   opt_state: PyTree,
                   x: Float[Array, "batch"],
                   y: Float[Array, "batch"],
                   dydx: Float[Array, "batch"]
                   ):
        loss_value, grads = eqx.filter_value_and_grad(diff_loss_fn)(model, x, y, dydx)
        updates, opt_state = optim.update(grads, opt_state)
        model = eqx.apply_updates(model, updates)
        return model, opt_state, loss_value

    opt_state = optim.init(eqx.filter(model, eqx.is_array))

    for epoch in range(n_epochs):
        for (batch_x, batch_y, batch_dydx) in generator_train_ds:
            model, opt_state, train_loss = train_step(model, opt_state, batch_x, batch_y, batch_dydx)

        test_loss = rmse(vmap(model)(x_test), y_test)
        print('Finished epoch {:3d}'.format(epoch), 
                ' | Train Loss: {:.5f}'.format(train_loss),
                ' | Test Loss: {:.5f}'.format(test_loss))

    return model

# %%
# linear_onecycle_decay_scheduler = optax.linear_onecycle_schedule(transition_steps=total_steps, peak_value=0.1,
#                                                                  pct_start=0.2, pct_final=0.6,
#                                                                  div_factor=100., final_div_factor=1.0e6)

total_steps = num_epochs * (len(x_train) // BATCH_SIZE) + num_epochs
lr_schedule = optax.cosine_decay_schedule(init_value=0.01, decay_steps=total_steps)
# lr_schedule = optax.linear_onecycle_schedule(transition_steps=total_steps, peak_value=0.1,
#                                                 pct_start=0.2, pct_final=0.6,
#                                                 div_factor=100., final_div_factor=1.0e6)

lrs = vmap(lr_schedule)(jnp.arange(total_steps))
plt.scatter(range(total_steps), lrs, s=1)
plt.title("Linear One Cycle Decay Scheduler")
plt.ylabel("Learning Rate")
plt.xlabel("Epochs/Steps")
plt.show()

# %%
def gen_data_dml():
    train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train, dydx_train))
    
    x_test = spots
    y_test = prices
    dydx_test = deltas
    test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test, dydx_test))
    
    train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    
    generator_train_ds = tfds.as_numpy(train_dataset)
    generator_test_ds = tfds.as_numpy(test_dataset)
    return generator_train_ds, generator_test_ds, x_test

# %%
def bachelier_train_dml(key: Array):
    total_steps = num_epochs * (len(x_train) // BATCH_SIZE) + num_epochs
    lr_schedule = optax.cosine_decay_schedule(init_value=0.01, decay_steps=total_steps)
    
    seed = SEED
    key = jax.random.PRNGKey(seed)
    key, subkey = jax.random.split(key)
    model = MLP_Normalized(key, in_size=x_train.shape[1], out_size="scalar")
    
    key, subkey = jax.random.split(key)
    model = init_linear_weight(model, trunc_init, key)
    
    optim = optax.adam(learning_rate=lr_schedule)
    model = diff_train(model, generator_train_ds, generator_test_ds, optim, n_epochs=100)
    return model

# %%
generator_train_ds, generator_test_ds, x_test = gen_data_dml()
y_test = prices
key = jax.random.PRNGKey(42)
model_dml = bachelier_train_dml(key)
# Out:
# Finished epoch   0  | Train Loss: 0.00008  | Test Loss: 0.05723
# Finished epoch   1  | Train Loss: 0.00004  | Test Loss: 0.04335
# Finished epoch   2  | Train Loss: 0.00002  | Test Loss: 0.03922
# Finished epoch   3  | Train Loss: 0.00002  | Test Loss: 0.03893
# Finished epoch   4  | Train Loss: 0.00003  | Test Loss: 0.03846
# Finished epoch   5  | Train Loss: 0.00002  | Test Loss: 0.03869
# Finished epoch   6  | Train Loss: 0.00002  | Test Loss: 0.03835
# Finished epoch   7  | Train Loss: 0.00002  | Test Loss: 0.03874
# Finished epoch   8  | Train Loss: 0.00002  | Test Loss: 0.03988
# Finished epoch   9  | Train Loss: 0.00002  | Test Loss: 0.04063
# Finished epoch  10  | Train Loss: 0.00002  | Test Loss: 0.03916
# Finished epoch  11  | Train Loss: 0.00002  | Test Loss: 0.03782
# Finished epoch  12  | Train Loss: 0.00002  | Test Loss: 0.03810
# Finished epoch  13  | Train Loss: 0.00002  | Test Loss: 0.03908
# Finished epoch  14  | Train Loss: 0.00002  | Test Loss: 0.03916
# Finished epoch  15  | Train Loss: 0.00002  | Test Loss: 0.03903
# Finished epoch  16  | Train Loss: 0.00002  | Test Loss: 0.03886
# Finished epoch  17  | Train Loss: 0.00002  | Test Loss: 0.03906
# Finished epoch  18  | Train Loss: 0.00002  | Test Loss: 0.03844
# Finished epoch  19  | Train Loss: 0.00002  | Test Loss: 0.03937
# Finished epoch  20  | Train Loss: 0.00002  | Test Loss: 0.03995
# Finished epoch  21  | Train Loss: 0.00002  | Test Loss: 0.03856
# Finished epoch  22  | Train Loss: 0.00002  | Test Loss: 0.03794
# Finished epoch  23  | Train Loss: 0.00002  | Test Loss: 0.03901
# Finished epoch  24  | Train Loss: 0.00002  | Test Loss: 0.03815
# Finished epoch  25  | Train Loss: 0.00002  | Test Loss: 0.03854
# Finished epoch  26  | Train Loss: 0.00002  | Test Loss: 0.03932
# Finished epoch  27  | Train Loss: 0.00002  | Test Loss: 0.03832
# Finished epoch  28  | Train Loss: 0.00002  | Test Loss: 0.03753
# Finished epoch  29  | Train Loss: 0.00002  | Test Loss: 0.03852
# Finished epoch  30  | Train Loss: 0.00002  | Test Loss: 0.03828
# Finished epoch  31  | Train Loss: 0.00002  | Test Loss: 0.03783
# Finished epoch  32  | Train Loss: 0.00002  | Test Loss: 0.03816
# Finished epoch  33  | Train Loss: 0.00002  | Test Loss: 0.03815
# Finished epoch  34  | Train Loss: 0.00002  | Test Loss: 0.03845
# Finished epoch  35  | Train Loss: 0.00002  | Test Loss: 0.03850
# Finished epoch  36  | Train Loss: 0.00002  | Test Loss: 0.03793
# Finished epoch  37  | Train Loss: 0.00002  | Test Loss: 0.03853
# Finished epoch  38  | Train Loss: 0.00002  | Test Loss: 0.03745
# Finished epoch  39  | Train Loss: 0.00002  | Test Loss: 0.03749
# Finished epoch  40  | Train Loss: 0.00002  | Test Loss: 0.03890
# Finished epoch  41  | Train Loss: 0.00002  | Test Loss: 0.03820
# Finished epoch  42  | Train Loss: 0.00002  | Test Loss: 0.03833
# Finished epoch  43  | Train Loss: 0.00002  | Test Loss: 0.03830
# Finished epoch  44  | Train Loss: 0.00002  | Test Loss: 0.03875
# Finished epoch  45  | Train Loss: 0.00002  | Test Loss: 0.03880
# Finished epoch  46  | Train Loss: 0.00002  | Test Loss: 0.03861
# Finished epoch  47  | Train Loss: 0.00002  | Test Loss: 0.03861
# Finished epoch  48  | Train Loss: 0.00002  | Test Loss: 0.03824
# Finished epoch  49  | Train Loss: 0.00002  | Test Loss: 0.03822
# Finished epoch  50  | Train Loss: 0.00002  | Test Loss: 0.03759
# Finished epoch  51  | Train Loss: 0.00002  | Test Loss: 0.03761
# Finished epoch  52  | Train Loss: 0.00002  | Test Loss: 0.03769
# Finished epoch  53  | Train Loss: 0.00002  | Test Loss: 0.03801
# Finished epoch  54  | Train Loss: 0.00002  | Test Loss: 0.03758
# Finished epoch  55  | Train Loss: 0.00002  | Test Loss: 0.03836
# Finished epoch  56  | Train Loss: 0.00002  | Test Loss: 0.03811
# Finished epoch  57  | Train Loss: 0.00002  | Test Loss: 0.03843
# Finished epoch  58  | Train Loss: 0.00002  | Test Loss: 0.03793
# Finished epoch  59  | Train Loss: 0.00002  | Test Loss: 0.03830
# Finished epoch  60  | Train Loss: 0.00002  | Test Loss: 0.03778
# Finished epoch  61  | Train Loss: 0.00002  | Test Loss: 0.03788
# Finished epoch  62  | Train Loss: 0.00002  | Test Loss: 0.03789
# Finished epoch  63  | Train Loss: 0.00002  | Test Loss: 0.03705
# Finished epoch  64  | Train Loss: 0.00002  | Test Loss: 0.03794
# Finished epoch  65  | Train Loss: 0.00002  | Test Loss: 0.03807
# Finished epoch  66  | Train Loss: 0.00002  | Test Loss: 0.03829
# Finished epoch  67  | Train Loss: 0.00002  | Test Loss: 0.03779
# Finished epoch  68  | Train Loss: 0.00002  | Test Loss: 0.03790
# Finished epoch  69  | Train Loss: 0.00002  | Test Loss: 0.03744
# Finished epoch  70  | Train Loss: 0.00002  | Test Loss: 0.03766
# Finished epoch  71  | Train Loss: 0.00002  | Test Loss: 0.03796
# Finished epoch  72  | Train Loss: 0.00002  | Test Loss: 0.03788
# Finished epoch  73  | Train Loss: 0.00002  | Test Loss: 0.03774
# Finished epoch  74  | Train Loss: 0.00002  | Test Loss: 0.03790
# Finished epoch  75  | Train Loss: 0.00002  | Test Loss: 0.03782
# Finished epoch  76  | Train Loss: 0.00002  | Test Loss: 0.03801
# Finished epoch  77  | Train Loss: 0.00002  | Test Loss: 0.03793
# Finished epoch  78  | Train Loss: 0.00002  | Test Loss: 0.03795
# Finished epoch  79  | Train Loss: 0.00002  | Test Loss: 0.03790
# Finished epoch  80  | Train Loss: 0.00002  | Test Loss: 0.03798
# Finished epoch  81  | Train Loss: 0.00002  | Test Loss: 0.03775
# Finished epoch  82  | Train Loss: 0.00002  | Test Loss: 0.03803
# Finished epoch  83  | Train Loss: 0.00002  | Test Loss: 0.03799
# Finished epoch  84  | Train Loss: 0.00002  | Test Loss: 0.03810
# Finished epoch  85  | Train Loss: 0.00002  | Test Loss: 0.03810
# Finished epoch  86  | Train Loss: 0.00002  | Test Loss: 0.03808
# Finished epoch  87  | Train Loss: 0.00002  | Test Loss: 0.03801
# Finished epoch  88  | Train Loss: 0.00002  | Test Loss: 0.03824
# Finished epoch  89  | Train Loss: 0.00002  | Test Loss: 0.03820
# Finished epoch  90  | Train Loss: 0.00002  | Test Loss: 0.03809
# Finished epoch  91  | Train Loss: 0.00002  | Test Loss: 0.03804
# Finished epoch  92  | Train Loss: 0.00002  | Test Loss: 0.03804
# Finished epoch  93  | Train Loss: 0.00002  | Test Loss: 0.03799
# Finished epoch  94  | Train Loss: 0.00002  | Test Loss: 0.03790
# Finished epoch  95  | Train Loss: 0.00002  | Test Loss: 0.03797
# Finished epoch  96  | Train Loss: 0.00001  | Test Loss: 0.03798
# Finished epoch  97  | Train Loss: 0.00002  | Test Loss: 0.03792
# Finished epoch  98  | Train Loss: 0.00002  | Test Loss: 0.03799
# Finished epoch  99  | Train Loss: 0.00002  | Test Loss: 0.03794

# %% [markdown]
# ## Plot results

# %%
pred = predict(model_dml, x_test)
plot_eval(model_dml, pred, test_set, "dml")

# %% [markdown]
# # Save trained models to onnx

# %%
from jax.experimental import jax2tf
import tf2onnx

# %%
def save_to_onnx(model, out_path):
    # NOTE: We need enable_xla=False because tf2onnx is not aware of some XLA
    #       specific TF ops (e.g. DotGeneral)
    nn_tf = jax2tf.convert(model, with_gradient=True, enable_xla=False)#, polymorphic_shapes=["(b, _)"])
    nn_tf = tf.function(nn_tf, autograph=False)
    
    nn_onnx = tf2onnx.convert.from_function(nn_tf, 
                                            input_signature=[tf.TensorSpec([model.in_size], jnp.float64)],
                                            output_path=out_path)
    return nn_onnx

# %%
out_path = "results/models/bachelier_model_normalized_ml.onnx"
model_onnx = save_to_onnx(model_ml.layers[1], out_path)

# %%
# save vmapped version

def save_vmapped_to_onnx(model, out_path):
    # NOTE: We need enable_xla=False because tf2onnx is not aware of some XLA
    #       specific TF ops (e.g. DotGeneral)
    
    n_features = model.in_size
    model = eqx.filter_vmap(model)
    nn_tf = jax2tf.convert(model, with_gradient=True, enable_xla=False, polymorphic_shapes=["(b, _)"])
    nn_tf = tf.function(nn_tf, autograph=False)
    
    nn_onnx = tf2onnx.convert.from_function(nn_tf, 
                                            input_signature=[tf.TensorSpec([1, n_features], jnp.float64)],
                                            output_path=out_path)
    return nn_onnx

# %%
out_path = "results/models/bachelier_vmap_model_normalized_ml.onnx"
save_vmapped_to_onnx(model_ml.layers[1], out_path)
# Out:
# (ir_version: 8
#  producer_name: "tf2onnx"
#  producer_version: "1.15.1 37820d"
#  graph {
#    node {
#      input: "args_tf_0"
#      input: "new_shape__960"
#      output: "Transpose__916:0"
#      name: "Transpose__916"
#      op_type: "Reshape"
#      domain: ""
#    }
#    node {
#      input: "Const_1:0"
#      input: "Transpose__916:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum/Einsum:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum/Einsum"
#      op_type: "MatMul"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum/Einsum:0"
#      input: "const_fold_opt__964"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg"
#      op_type: "Neg"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp"
#      op_type: "Exp"
#    }
#    node {
#      input: "const_fold_opt__967"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv"
#      op_type: "Reciprocal"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul"
#      op_type: "Mul"
#    }
#    node {
#      input: "Const_3:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_1/Einsum:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_1/Einsum"
#      op_type: "MatMul"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_1/Einsum:0"
#      input: "const_fold_opt__971"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_1"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_1"
#      op_type: "Neg"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_1"
#      op_type: "Exp"
#    }
#    node {
#      input: "const_fold_opt__967"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_1"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_1"
#      op_type: "Reciprocal"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_1:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_1"
#      op_type: "Mul"
#    }
#    node {
#      input: "Const_5:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_2/Einsum:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_2/Einsum"
#      op_type: "MatMul"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_2/Einsum:0"
#      input: "const_fold_opt__962"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_2"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_2"
#      op_type: "Neg"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_2"
#      op_type: "Exp"
#    }
#    node {
#      input: "const_fold_opt__967"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_2"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_2"
#      op_type: "Reciprocal"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_2:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_2"
#      op_type: "Mul"
#    }
#    node {
#      input: "Const_7:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_3/Einsum:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_3/Einsum"
#      op_type: "MatMul"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_3/Einsum:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/BroadcastTo_3:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_3:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_3"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_3:0"
#      input: "const_fold_opt__963"
#      output: "Identity_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit__squeeze_/Reshape"
#      op_type: "Reshape"
#    }
#    name: "tf2onnx"
#    initializer {
#      dims: 2
#      data_type: 7
#      name: "new_shape__960"
#      raw_data: "\007\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 1
#      dims: 1
#      data_type: 11
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/BroadcastTo_3:0"
#      raw_data: "\301\234\305\211\t\303\314\277"
#    }
#    initializer {
#      dims: 20
#      dims: 1
#      data_type: 11
#      name: "const_fold_opt__971"
#      raw_data: "y\227&\221\3544\262?\350\324!\316\200S\265?\021JL3\036\037\246\277\262\326\365\'B\355\221\277\253\370\272\206\273\013y\277\310\373\313\233\230\000\235\277f\355\327<\334\327\274\277\3473z\\\337\302\276?\345\035\342NQ\234\301?`\004\335|\t3\310?:$\237\352\324\t\301?\371\016>\243G\364\306?h\350\343\251,\261\254?\224\220\017\205J\017\262\277\023\367\037\307\234\224\262?\t\211\211\2303R\304\277f\351\241\t@\301\240?K.X\346\321\327\274\277\205\3358\205b\014\223?^\366q\330\300\023\306?"
#    }
#    initializer {
#      dims: 1
#      dims: 1
#      data_type: 11
#      name: "const_fold_opt__967"
#      raw_data: "\000\000\000\000\000\000\360?"
#    }
#    initializer {
#      dims: 20
#      dims: 1
#      data_type: 11
#      name: "const_fold_opt__964"
#      raw_data: "\341YFq\225S\246?1<bRy\360\322\277\207\276<\213\255\350\275?o\256\330\324\351s\255\277Sx\022\034\t8\220?\226\220v\301\355\206\210\2772\021\324\334\341s\223\277\352!\271-+\037\252?\326\302\333\360=N\254?ud\231PHIz\277\220\022\356a\037\271\313\277\207%\205\252\\\014\303?\004:\237r\033\211\313?\355\345\213-\'\213\252?\027Im&%\353\320\277I\205\033|2`\274?!\366w\277\331\337\243?\224\300\375eX\242\275\277m\220&\225\261\325\314?\004\355\376 H\246\312\277"
#    }
#    initializer {
#      dims: 1
#      data_type: 7
#      name: "const_fold_opt__963"
#      raw_data: "\001\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 20
#      dims: 1
#      data_type: 11
#      name: "const_fold_opt__962"
#      raw_data: "\324\265\367-\233\262\265\277\243\'l\276\376>\264\277\313\257\222\'\304\262\277\277\322Aq\341`\225\262?\035#c\205-\223\275?\024_\n\206\321\204\300?\272\333*\371\372\357\302\277c\006\302\276\362\372\256\277\201i\340E\255\342\274\277`\274\322\265\236\242\245\277\250\263\027fr\000\210\277\275L\275*\003\244\311?\241\316\351\234\244{\315\277yxf\356t)\300?j\330\350~I \317?\221%\201\3742q\231?\365\r\320\024\r\222\303?\024&pD\362\026\265?n\270\232\322\254\232\266\277\027\036\273\302o\354\307?"
#    }
#    initializer {
#      dims: 1
#      dims: 20
#      data_type: 11
#      name: "Const_7:0"
#      raw_data: "\020\030@\2600\327\324?\245\252sFJ\376\305?\263o\013\t\250\247\347?\203\336\n}tI\341\277tU\205f\337\212\343\277\234\013\177\313\306\032\343?m\310Q\013\242\241\243?\250R\373\344\006\247\220?\273\002\3456\325\261\330\277A\355^Z\225Q\220?\367\315\273\266+\347\331\277H^\242\304\316\372\337\277\3655I\334\3519\311?\010\317]\227\262[\323?\274\021\316\030\362\035\313\277v,\260\001$!\337\277j\314\231Z\371\207\334?\3155\010n\217=\335\277<\376\315\263{\024\343?\224\355uD\346\262\336\277"
#    }
#    initializer {
#      dims: 20
#      dims: 20
#      data_type: 11
#      name: "Const_5:0"
#      raw_data: "\234e\267\257\216\321\233?P\025\010\030\230\320\301\277\364LnX\267\311\320\277\233\305\2764\'\356\320?\324\327\300\372\202\354\307\277\021\205\020&\251\210\301?N\220\276\271x\337\276?\336\004\310\363\020U\234\277\271\212\271;\030F\274\277\216\375\036?\'\303\314?\355u\343Y\010?\245\277\344Y\322\247\241Z\325?\326\006O\376\314\024\206?n-48\247\340\320\277s&\256\223\366\321\300?]|<\375:\"\305?2=\271\354P+\254\277\266\3064:zAu\277\377M0\002N@\322\277\330\024\227\351q0\322\2771\365e\021Z+\304\277\362\225\206\325Zh\274?\312g\354\337}\027{\277\256]\317pj\263\271?\321\336\3705 \212\265?\236\226j\310]9\220?\3445w\363@0\307?\226sh9\024\245\264\277\264\260\354\371\377)\230\277\302\247@=\0168\247?\312\177(J[\266\300\277Go\366\302)\371\327?!\257\355\356\324\000\260\277E\311x\037\006\365\250?\"\225\r\177\365-\322\277\003\360a\003\2332\264\277\356\253\320qc>\273\277\255\205pC\\\360\323\277\262j\216\177\027I\306?\"\276\013\027\314\361\303?\224\206\026g9-\312\277o@jc\004\016\307?h\237\266\217l\030\267\277\337\021\035C@\253\302\277\013\261\200\0339\343\237\277\275\004\311?v\343\332\277\322\337\204W\346\014\266\277\226\206\024P\273?\305\277\351\226\301\210\370p\304?X\"V\330\217S\234?\232z\272\332$\243\307\277\351d\322\002\264i\330?O\347\337+\212\370\315\277j\224A\370D\270\277?\221\336\270Ox\346\273\277/U,\302\235]\321?J\013\331\330\026M\303?`n\324\016K\256\326?U\337,\246\210<\317\277\036c[z\222\260\340\277\355 %P\225\372\306?\232\237\335\226Z\013\240\277\001\254\213\270\331\261\227?\304\221\037\2117\341\306?\242:\210\243!\271\265?\270\322a\200T\200\320\277\316\357\037\254d\035\250\277s\275N\341\201\233\317?y\\Bmt\325\314?\273\301y\245\335\235\311?J\207\216UP\002\330\277\"\267\223\311f\016\305\2778\376\222\203k\272\321\277\221\260\207\204\341\321\315?\336-\010\230v+\244?&)\316z\216\334\300\277\302}\356\272i \222?\302l\216b$u\323\277\tS\3252\271e\333?\347\230\271\032\220\371\245?\033\246XW\226\237\325\277i\215\364P\033\320\246\277\361\321/\353#\354\317?\222\356\001\340\260\364\276?[W7Lr\367\333?2\275Y\304\354\331\326?\273\016\023;\234\317\246?-M\336tx?\272\277~C\236\204\345$\260?\321;\377\271\260\230\260\277\254\255\244\217\267L\327?`\345\233\357\243#\324\277A\222\001\363R\277\317?\246\336\355\345\201A\276\277\3749\334\212\005\247\274\277>\357\"\272\254\317\235?\266,u\231z\250\331\277e\240:&2\243\256?\357=\027#!\233\311?|\0013A%x\314\277\313P\021;\333\037\312?\357@\177\2137g\327\277\"\217\2108\243\225\252?\336!q\336\n\301\246?\222\365\325\nZ\244\323?\321\245\360g\266F\232\277\311m\004\307\210\226\237\277]mP,\212\260\306?\325\034\217\205/\230\240\277\033\357\033\2351%\324\277\3754\215\016\322a\270?d\023\r\304\033\363\340?D!\210r\360\267\336\277\255\001\275\030U\374\263\277h\360\246\036\260\312\333\277\303\222\347\357\327J\223\277]\220\'\350\313\351\240?n\246\276\377Q\327\330?\236]\316\251eU\327?A\007\010@7\365\321\277\n\022O\277t\200\225\277\034\2229\271\013\360\270\277\220VLv*Z\332\277\037\273\253\262r \336?\t\305\316\2435\"\264\277!\031|:\';\335\277\301\\\353\226\270\t\327\277\305\236\205\374\303\257\324?\'\370!)J\027\330\277*\"\302.n\314\277\277q\367[\333\335\203L?D\217.\314\327\017\253\277[\224k\203\270\335\204\277\355\245\210\270\304o\310?\320<\037O\322\234\303\277L\362;\327\352\002x?LY\211\2543\032\306\277\344Z\346\25667\266\277\200\033\271\351?d\274?h\254\237\306=\233\261\277\256\342o\247Rk\252?\221z\320\013\234\243\313?\335e\247\315l\205\323\277\000Pn\220\340\314\332?&\000~\021\235\363\312\277\037\\\n\036\361\305\302\277\263s\357$a\002\330?+&>\271z\221\223?\270\376\222\332\310\273\314\277b_\330\226\267\020\313\277F\260=\333\206#\313\277s\203\032\365:\300\261\277)\000\245\256\330\025\310\277\274L!k\357\300\272?\016\005\"\264\365\301\311?\254:\320\235\260\335\224\277j\014\365\021[n\322\277\3235/1f\216\322?\326W\324\331\334\210\310?a\261l\314a\270\263?\350I_\247\221l\302\277\374\246\3050\241a\320?O\261\215\314\323\331\304?L\226\233\364j\221\330\277X\361\355ZU.\323\277\304\350\316\0078\025\323?=#L\275Gd\315?/\021:\354\265\204\232 ...
#    }
#    initializer {
#      dims: 20
#      dims: 20
#      data_type: 11
#      name: "Const_3:0"
#      raw_data: "\tj\007\177@t\311?V\351\022\033>_\334?\247\315\332-\005\302\303?C\225 N\313-\300?\356\217\231\370\213\024\337\277\366\275\023=\315\315\301\277e\030Q\335\323\003\307\277\376\264\347 n*\304\277g\255\327\253\245\240\303\277\004\366IuY\302\277\277\201\353y\264\225\320\301?\256\257\266\350w\031\327?\323\361xb\024\"\332?\003\341\335P\2644j?\366Lo\247E\206\302\277\354\007\212\231@\243\245?\301\233]\026\312\311\245\277\000\370*\315\236\t\327\277\303\266\\\241\3354\271?\2077\344)q\256\325\277\274\264\367\343u_\325\277\343\032.\031\360\346\330?\253/\225\004%\"\333?C\221\317\324\016\002\340?\302\264\276\205\301\272\323?\253\237\253\001\331\336\312\277\301\254*\2628l\316\277\211\370\2346\226n\331?\340O%\227\257\276\310\277\312oy\3740\365\306?.gR\215\334\345\324?9S\250u\374\025\267\277\211\357ZU\332X\321\277\005\371\220W\024\275\243\277\261g:\003s\322\261?%68\rv\217\260\277\000:C\022p@\323\277z\377\317\321cT\204?G\0344\237g\226\324?\033\301l\317V5\306?O\321\222\257?\230\303?\350\311\033\032\232-\310\277\366I\271\215\302\026\320\277[\353\274U\317\316\324\277\207A\312I{\374\226? \026u\370\216\234\270\2778\007\271\355\007R\264?#\345u!o-\252?c\375\264\211\366\r\240?Za\314\301\231:\314?,\362\264i\320\352\315?\346\340n\005\354r\302?F\225\010\357y\030\274\277\036\375m\230\021*\272?\346{I\213\016\004\306\277\264k\336_\r\273\312\277?\253\3709\315z\276?\365\272\357\330Pp\301\277\244\253\302\352N\350\340\277q\034+q\021z\312?%\361\027%\301\037\314?\360\333\3229\220\371\305?\302\351\227\342B\355\270??d@\177\207\004\337?\247\310\314p,\324\317?\202H\340\277\347@\331\277\260\266\014\271\302\374\300?\301\017\006\366\367O\321?\367\224\216\2273p\275\277\205\177\271\202\312\373\262?f=\014\250\313\277\254\277\305)8\357\032\305\307?\262\\E\337\366\245\312?Na\264\006\224M\237\277}\224\265\320Tj\332?Kv`S\034\022\305?\357\210\2036f\031\314\277\234R\207\225pu\262\277\260R~A\313p\274?\257X\276\016/\327\306?\226\327\334\372\217\201\270?u\275\212\177\351\211\300\277g\261\267\226\362U\306\277\310[\250\2142\242\264\277\235\242\331\335S\335l?\354.\337\321\247\361\321?\260xQ\220\021k\250\277q\207\2742\206p\312?\211\324\357:k\004\302?\314\372\265t\020\274\307?\347\270H\241\177q\224\277\274\\\222\334+\'\266?5QA\336\3675\312?w`e\227\240J\327?\2115[\206\253`\334?\n\007\276\204\330j\230?PscK\027\277\342?\001.&6\310\\\274?3\231#\242y{\335\277\377\302\005\226k(\271?\244\322\216\031\330\022\274?\026\214 \274\253>\261\277\027\361\367\271\360\254\303?:7I\360Fe\306\277\2216$\265C\001\207?\247\365k\363\2618\204\277\r\336\347x\245\205\275\277\201v\3259\374/\312?\007\037N\336\'?\332?:GS{\225\362\241?\233\327u\022\302\316\203\277c\026\206\250\372\276\312?\031\007\010\263\373(\306\277W\303\357\227\330\221\230?\247\2421\325\242\207\244\277#\235t\245s6\227\277\316[\320.*\214\257?\351<\365\351cc\302?I\361\352\213W4\256?\254`Q\326\301\227\271?\004 \212#\374\364\244?!\026\357\351\002\253\264\277\021\351\304\372\r)\322\277\026L\234\000\351\341\330\277\256\310Oq\266F\330?6W\225\224\034g\323?\'G\365Z\217\\\311\277\242\350\306\363N\037\313\277=\r\310\313\0057\304\277\274\347\246\270iJ\327\277k\024\263H-,\222\277W{\247\253sK\213\277\244DT\335\377\234\300?eW\026\016d\330\320?:G\354\370\277\003\321?\374\322\024\360\021\251\247\277bkP\242\027\330\310?#\247\333\010\300c\270\277+\273\263V\310\'\270\277\205\217fY\243\261\316\277\256\312/\306\252\016\271?\346l\272i\247%\322\277\301p\212\235\235$\263?\262\020i\342,@\305\2779vvEt;\271\277s\213_\226\3337\310\277\364\014\343y\357J\331?\345(\216\212\364Y\301\277\277\272\257\021\007\241\273\277h\301\035>|I\300?WP\256\'\362\276\303?\267Y\307\256h\216\315?\235(\367\016\233\343\324\277\010\316\351\340X*t?\345w\3607 }\302\277\005\227\261|H\177\331?\207\234\225\331z\275\327\277\0343\274\260\216\377\255? :\224O\261\022\305?\323\004\352\212f\002\320\277\230\317CrS\210\270?Y\026\240\032FW\320?\017\360\247x\371X\235?>\241\236\242\377\355\311?\246\376n\321\037\024\300?\347K\'\302\317I\312?\000\262\324\235J\343\300?:EGYp\324\260\277[\246`\316\226\252\240? ...
#    }
#    initializer {
#      dims: 20
#      dims: 7
#      data_type: 11
#      name: "Const_1:0"
#      raw_data: "\336\260\\\t\250\364\320?\002Vc7D\007\325?\246\037\301\313QN\245?\305\020Y>{e\243\2777\003[\261Em\323?\354\262\265\207\310\261\242\277k\217\211\331\240\007\307\277\250.(\3229\205\321?\224\362z\213\264\363\251\277\261:\317\345)\367\341\277\343\265\025|\027R\254\277\340\211f\006\020\317\321\277\361\262-\341\2646\230\277\332\034\350u\0200\250\277\031G\2340\346\026\330?5V\177\210\024\020\315\277Lf\370=q\'\276\277%\212 O \211\303?\366cY$\030\367\252?\037O\340\337H\356\261\277\232\206\343\207r\030\300?\001\016\332\362\"\021\305?\356\231\325\330\316\227\250?\222\377j\322\200\024\341\277\306\035\303\2266\220\340\277\321\313\t\3406\226\324?\334+w\026\234\004\320?\341\255\0041\255<\333\277\220\200*\312\005\313\274\277\340TZ\313V\206\262\277\007p\351\300A@\323?\347\021\250pB\356\330\277\314P\022\323\235\021\330\277\203\010\000f\323\036\327?\311?\322\t\324J\275\277\371f\327d\034\234\312?\024\207E\215\250q\310?\322\006`\261z\216\334?\323\363\361\025:\201\341?\0256\322\326\2459\267?\270\230)\031=\260\304?\336?l\024\214\020\345?\271\217+\001m\340\205\277\032\200\372\272#{\331?OL\033\025o\201\277?\n\235\316\257\313\300\262?k\363\263\340\000\337\264\277\006\343kJK\215\241\277ot\'!1n\315\277\315\033\317\344h\010\317\277\347\211,\016\336;\270\277\277\206\244z\335\365\277\277\374\3776e>r\304?j@\261\200\325\231\277?X\037b|\320\333\272\277\262\226\025C\307\327\315\277\277\234e\360\260\014\323?e\374#\034\322,\331?\313\246\252QK\341\315?\261\276\006\331\272H\321?\265\346\0303\333}\255?\351\021\t\247\360\372\341\277\340/\335\321\010\020\307?g\274\370A\212\307\304?__Q\317\243>\337?\307\\\231\316\370o\330\277\'\tdc\243\254\234\277\311HF\353\273\002\252\277\022F`K\246\205\326?\'\277Z.7\354\235?\203{\241\211\252\256\252\277\223L\\X[\305\267?r\024\262\247\273H\305\277\030\312\277A\352\223\263?\355\360l\272\030\232\337\277aA`\nl\371\267?~\200K\353\036J\313\277Z>J\365&\334\323\277\036\014\235`\264\201\301?\237\031\224;\235\341\341?MO\022\223nH\316?\006\003.gH\314\326?\262\021+Z<\324\247?\024\037k\017\307\321\304?\335\206\207\371\326\214\310?\037\322l\234\017\237\332?\355V!\377\027\200\340?WTN<p\023\342?\337\224\025\222\020\0178\277h\322U\373`\251\307?k\363\327\351D\025\340?\026\277\230\221!\262\305\277\026\364\204\000\017\017\331?\247D\336\277\262\367\341?\304\"`\241(\256\206?\365\000g\024K\032\322\277h\346`y\264\001\323?\207\254\246\227\272@\344?\213X\316\n\030\001\272\277\201P`*\344\031\325?\004\272y\"O\270\326?\r4Mu\335\213\343?\221\221\251\202#3\264?\337\261\nk\314\240\326?gp\224\365un\327?\231\226\246eSI\273?\277\251\3544\241Y\332?\347`b`\235F\261?\245\350\313\010\246\305\306?b*\376\255+T\252\277rc\372\207\374x\255?me\020h1n\322?\226\370\245\252\254/\245\277\361Le\221\323\227\326?\352\251*m\200\245\244\277Fp(\225x$\306?\2741\036z\3649\316?\271\270{\237\200\225\322?\211\232p\336\353o\317?=[80|id\277\363\327\234y\370\224\336\277\354\252\355\320_z\215\277\311\227Ek\257\217\311\277u\303\217\331\3648\327?W\311W\323P\\\322?\032\224\001\331\'\241\326\277\304\210\353\247\275r\313\277Z\022\227+\366\200\312\277\254\323\214\221w\005\322\277L\343Hcoj\335\277^k\032\306\351\'\306\277\323x\006\276}\212l?\225\223\010\367\337\"\277\277N\364\2754\3377\325\277:\030Q\177z\377\332\277\371\253\022:#I\314\277i\363\352\360\245\364\251\277\350\276N\212\222\236\302\277\302V\017\251DY\307\277\324\272\241\326\210 \342\277"
#    }
#    doc_string: "converted from b\'__inference_converted_fun_tf_32294\'"
#    input {
#      name: "args_tf_0"
#      type {
#        tensor_type {
#          elem_type: 11
#          shape {
#            dim {
#              dim_value: 1
#            }
#            dim {
#              dim_value: 7
#            }
#          }
#        }
#      }
#    }
#    output {
#      name: "Identity_1:0"
#      type {
#        tensor_type {
#          elem_type: 11
#          shape {
#            dim {
#              dim_value: 1
#            }
#          }
#        }
#      }
#    }
#  }
#  opset_import {
#    domain: ""
#    version: 15
#  }
#  opset_import {
#    domain: "ai.onnx.ml"
#    version: 2
#  },
#  None)

# %%
out_path = "results/models/bachelier_vmap_model_normalized_dml.onnx"
save_vmapped_to_onnx(model_dml.layers[1], out_path)
# Out:
# (ir_version: 8
#  producer_name: "tf2onnx"
#  producer_version: "1.15.1 37820d"
#  graph {
#    node {
#      input: "args_tf_0"
#      input: "new_shape__1018"
#      output: "Transpose__977:0"
#      name: "Transpose__977"
#      op_type: "Reshape"
#      domain: ""
#    }
#    node {
#      input: "Const_1:0"
#      input: "Transpose__977:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum/Einsum:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum/Einsum"
#      op_type: "MatMul"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum/Einsum:0"
#      input: "const_fold_opt__1027"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg"
#      op_type: "Neg"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp"
#      op_type: "Exp"
#    }
#    node {
#      input: "const_fold_opt__1033"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv"
#      op_type: "Reciprocal"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul"
#      op_type: "Mul"
#    }
#    node {
#      input: "Const_3:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_1/Einsum:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_1/Einsum"
#      op_type: "MatMul"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_1/Einsum:0"
#      input: "const_fold_opt__1028"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_1"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_1"
#      op_type: "Neg"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_1"
#      op_type: "Exp"
#    }
#    node {
#      input: "const_fold_opt__1033"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_1"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_1"
#      op_type: "Reciprocal"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_1:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_1"
#      op_type: "Mul"
#    }
#    node {
#      input: "Const_5:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_1:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_2/Einsum:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_2/Einsum"
#      op_type: "MatMul"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_2/Einsum:0"
#      input: "const_fold_opt__1029"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_2"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_2"
#      op_type: "Neg"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Neg_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_2"
#      op_type: "Exp"
#    }
#    node {
#      input: "const_fold_opt__1033"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/Exp_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_2"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/AddV2_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_2"
#      op_type: "Reciprocal"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_2:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/pjit_sigmoid_/truediv_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_2:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_2"
#      op_type: "Mul"
#    }
#    node {
#      input: "Const_7:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/pjit_silu_/Mul_2:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_3/Einsum:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_3/Einsum"
#      op_type: "MatMul"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_matmul_/einsum_3/Einsum:0"
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/BroadcastTo_3:0"
#      output: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_3:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_3"
#      op_type: "Add"
#    }
#    node {
#      input: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/AddV2_3:0"
#      input: "const_fold_opt__1025"
#      output: "Identity_1:0"
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit__squeeze_/Reshape"
#      op_type: "Reshape"
#    }
#    name: "tf2onnx"
#    initializer {
#      dims: 2
#      data_type: 7
#      name: "new_shape__1018"
#      raw_data: "\007\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 1
#      dims: 1
#      data_type: 11
#      name: "jax2tf_unknown_/vmap/eqx.nn.MLP/eqx.nn.Linear/pjit_fn_/BroadcastTo_3:0"
#      raw_data: "I\264\310\366\275\324\320\277"
#    }
#    initializer {
#      dims: 1
#      dims: 1
#      data_type: 11
#      name: "const_fold_opt__1033"
#      raw_data: "\000\000\000\000\000\000\360?"
#    }
#    initializer {
#      dims: 20
#      dims: 1
#      data_type: 11
#      name: "const_fold_opt__1029"
#      raw_data: "a\021\216\221^\037\301\277\266\362w\315\250\313\300\277\321\366\032\250y\321\276\277\315T\337d\347^\217?\363\336\253\337\211v\262?\306?@\260/i\304?6\250Q@\000E\302\277\225N\010\231+d\312\277%\274\0014\004\n\303\277d\237\235\300z\341\245\277R\243\253\026[K\202\277\307P\216\207\257\277\310?TL\227\265M\023\321\277\301n+\"\247\022\262?K\265\231\336 \346\315?\224S\350\205)\220\244?H\334\205/\320[\271?\026\277N\300\2737\266?\321<\300s\315W\301\277\265fZ\302\355\371\301?"
#    }
#    initializer {
#      dims: 20
#      dims: 1
#      data_type: 11
#      name: "const_fold_opt__1028"
#      raw_data: "L\312\221\234\274-\241?\002\305\021\t\265\326\306?\357\304\221\346\316\325\261\277\360q\370\316\3453\261\277\347\267\257\r\230\227\277\277~\337\265\234\035Q\265\277HL\017t\205\351\310\277\277\260\2223d3\302?\242\304n\250\231\333\262?\242\t\330\276\366\033\305?\312$\320\275;\025\271?~\361\177-\206\317\307?\241\306\306\236\207)\242?\266\213bS\255\024u?~C\'\373k(\246?\340\223yLs\306\307\277\013)\027\354%h\257\277\221d\016\315\n\257\276\277\200x/\203!h\261\277\363\301\363y-\013\306?"
#    }
#    initializer {
#      dims: 20
#      dims: 1
#      data_type: 11
#      name: "const_fold_opt__1027"
#      raw_data: "\350\325S\303\207\003\264\277\2629\354\324\347m\313\277Z\312\234\262*R\251\277\261J\247\354\213\203\270\277\220^\302^p\323\320?\024\013\371\313\256\312\224?_<\214J\001\004\260\277\277Me\017,v\253?T\203h\250\001v\276\277\300\234\254\313\213\371\\\277\347\273\222\354\304N\315\277\177\233\266\021*V\277?\262\335\311\360\264|\306?\246\270\245\022\305}\240?1.\252\340\334\367\327\277\245s\3134\357\242\255?\323.\236\225\301\347\262\277\311\316\2149s\343\266\277\035r\014L$d\321?4\242\341\322|\233\316\277"
#    }
#    initializer {
#      dims: 1
#      data_type: 7
#      name: "const_fold_opt__1025"
#      raw_data: "\001\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 1
#      dims: 20
#      data_type: 11
#      name: "Const_7:0"
#      raw_data: "\216L\351\202\213o\320?@\360\352\323[V\264?\323]V \241\230\344?\'as\271\202\335\325\277\013\274\2128&\000\340\277|e\343\220\373\266\342?\226\235/\220;\332\212?ey=\333_\336\247?*[\361\036#m\315\277\252$\365\232~pi?\017\271\317\357\323\262\320\277\"!d\335j\'\327\277ba\"\351q\004\300?\036\373\013\330\362l\311?,\242D\226\236f\262\277\354J\205\340\304\003\337\277C\212\335&\221c\325?\272\036\203&N\017\332\277\347\255\253>\003\344\340?\277\337+M\332\313\323\277"
#    }
#    initializer {
#      dims: 20
#      dims: 20
#      data_type: 11
#      name: "Const_5:0"
#      raw_data: "\032\035\267\325\2375\225?1y\337\243\271\024\305\277/O\226\202\355\"\311\277\362BX0\013\264\323?\022TD\272eC\261\277y\242\201\305\377\233\312?.\226\312\"\230v\303?\'\233\377]7\345g?\233\036\236\266]\367\304\277C\305\257\032`\320\321?\276n\037w\307\021\256?\244\025o%)u\324?\264\242\307\212wW\260?\233\232\033\333\272\221\327\277\302+G\225Y\317\327?\267\026\031\263?\207\306?\201B\346\001z\331\264\277,\301\226\000\231c\203?+?u\374\332\031\315\277\254\272\357\032\267\300\317\277m\017\033e9\217\301\277\231\260r\321\371\272\271?[U!\232\205u\274?\317\231m\001\317(\304?\367B!fl\333\312?:\202\225\204p|\265?\013W\277\363\221u\311?\230\355\036\200D)\241\277L[\356SM\355\265\277\252&pBVa\262?Bg\357\t8\225\211\277 )\301\n\222G\326?\371e}\333t\037x\277m\244/olN\237?0i\370\315{\316\301\277\363~a\271p\026\271\2774\r\034\201\326c\263\2779\270\275GM\351\324\277\250\213e\261\t\207\315?\363\200\242\367;\250\307?>\256\350:\360\355\306\277\027\260\216\324\272r\300?\267%\304\240\3335\251\277\t\375!d\3027\271\277\272\002C\334\265\360n?\nC\220\376\023c\331\277\307;V\033>k\257\277\351\277Cj\r\367\277\277\343\231\234\325kg\264?\246\310\305z\216\261\266?\262P2\212\305\312\303\277\274\205-r\262\212\327?\274*\326\3007\340\313\277\313\310\356\273\230\341\305?&e\303\342d\266\222?\010,\202\351\203<\320?0\351\301\212\363\375\266?\317\215\266gE\236\325?\251%\221\315\223\237\312\277\177\265yv5M\342\277c\0239\221W\232\303?\266\t)<\230\377\207\277!\220\244@\021k\243?\231vg\326\025\350\311?\034\nA\234\245U\277?\300w\030T\317O\322\277\344x\355\020|\365\262\277\201\023\367\257+l\320?G!\335h\314\262\322?Y)\212\007\312\337\310?\206\374\345q\326\275\330\277\343\326%\214\302<\320\277x\020@\303\222\261\321\277\340\025)\211\'b\314?\204\221k\333r\014\260?\256\375\350(\006\001\301\277S\017\230\235g\320\274?\303CwN\304\335\324\2775\356\366 \315l\330?,\310\3324D\312\227?\273\200R\227\3739\334\277\223h5\033n\274\255\277\252o\371lw\350\320?\372\303%\365\371x\302?\361\205\360\204\372\342\326?\355_\365S\237\324\323?6|\375\374W\027q?\252\016\033-\017\256\260\277\0011\330\231-\313x?\014*\337\256\376\202\274\277}l\264\264\337\343\312?\n\314B\332\235J\335\277\206v\366\232\274\205\311?\245\265~\016\214\010\262\277\276\305Kf\347a\306\277\217\372<\371\303\244\204\277\332\336\'_\030v\331\277:\276\225\020c8\207\277\305f\032,\372?\275?8\270\202[\252\262\315\277\235k L\367\207\315?y\\ Xq(\324\277oO\222\367v\006\267?\277?V\264\250\\\277?l>\333\252+p\322?\023k\224\255\236\231\210\2778\r\257f#\227\215\277\234\030\265\317\010\004\305?:\377\263W\306i\274\277\207-Ie\017\210\322\277\314\2655\346Ag\300?S\202\010\024M\350\341?\323\307{G]2\340\277e\364^\216Nv\267\277\004/\274\242\262\n\335\277\344\327\376||\031x\277\201\327\260\'3\311P?\177\321y\035\364\325\330?U\033\001C:\231\331?\217tpz\377e\326\277[B\343\274\t\034\303\277\252\257~\357m(\302\277M\332<6\261$\341\277\235\223(8\356\307\341?\237\246\026\037G~\235\277)\330%\203\233\310\334\277j\255E\307\300X\323\277\207\301b\366\261\376\317?X{\250\366\223\020\326\277\321\362\202\205Ym\272\277\013\247SZ\006\\\321?eL\337\372n\274\206?W\235\246-\270\267\272\277\335\361TE\031\236\320?\263\343uq\006\351\300\277\255\203\003\214\277\037\257?;\326\202JKt\321\277\010\232\226#X\311\231\277\034\241\277^\016\231\310?\002\241\326\020E:\305\277\215~\023\317\253\022\303?\352@\334k\211\013\271?>\034\311Y\035\347\270\277\302\030\304\214\0052\304?\342\0055\247\300\036\327\277\272\325\307~\262\206\316\277\335DC\255\260X\322?a\255\332\306F<\310?\013\001p\2671S\337\277\332\337\002G\210c\322\277\036d\251L\013\217\335\277\315\004~O\360\233\307\277L\225\2116\311\213\272\277\227\221#\330\207\034\233\277#\001C]\325q\313?\225\266\020\347\260#\307\277G\255\247ZD[\327\277\024[}x\021d\303?HY\014\205\200\'\267?\267-\361b\307L\305?\216\247P\364\032w\310\277\377\373\024m\361\276\322?\013\330\000\206\307\010\302?\n\251,\330\020t\332\277:\204\217\\\216\355\326\277\t\020\201zH\251\317?g\202\004\225G\237\312?\006\331\0259:\004\230?8TTC\006\223\321\2775\310\241\001\221\367\260? ...
#    }
#    initializer {
#      dims: 20
#      dims: 20
#      data_type: 11
#      name: "Const_3:0"
#      raw_data: "BC\203T}\336\266?\240\016\364\332\350\235\324?\013<PT\375\t\304?\177\227]B\251\324\324?.\324\240\0053$\351\277\036]\245}\243\030\315\277\256\002\346T\300l\327\277\244n\035\237&\005\304\277\374\330\361~5\373\314\277h\033E\244\274\336\315\277}\225\"\204\010\235\213?\253\301M\r\367=\325?\214f?N\355\016\325?\2043:\373\375\266\230\277\032\320\233\235\364\301v\277\225\270\261jA\333\271\277\270\341\312T=L\240?F\216\341\037R\360\330\277\303}\206\265@\r}\277\007\315\370\252\361\017\344\277\314\2725b\345\204\327\277\002\2225\277RC\320?e\007m\261&d\330?\222_/\254\371\235\335?A+\326(\224\317\342?\330w\242:\2447\313\277\356\325\354\246\366 \332\277i0\332n\342w\331?\207\242B\325\225a\307\277\277\303g\217\356\310\322\277\026M\000~\324{\320?\\!u\023S\004\266?\210e\252\261\237\024\321\277\266\001\330\r\362J\323?\314\031\234u:\036\250?\2762\372\032k\025\256\277\364\375\023d\374:\327\277\250\214\251R \004\303\277\274M\320\002>2\332?\214\357\353\365U\364\244?\207O\260:?c\313?\036\212\032\265\245t\313\277C\311\031\272%o\267\277;B0\377i\321\321\277\250/\250\236\017\234\320\277\235\344\035\030K\341\303\277Q\322]dGc\271?\343\336fC\035\362\230?\351\202.y\224\250\245?\027\361\303S\303\277\313?\3230^\261\343\352\315?\036i\004\323g\320\276?\254\243\351P\261g\304\277\033\016\334e>\275\261?.u\247\255\373K\302\277\n\240d/\233!\314\277\016\222\251\220\307\244\304?\334\225\314E\233t\306\277\215\014\202D\242\340\345\277\370\017\313\244y#\307?Zj\326\353\034\037Y\277z9o\013c0\336?\320\214\341\031=h\271\277\023\251lC\361\270\334?\016\231\261\033\221\217\323?\321\312V\362\3532\341\277\033a\360\253\316\377\305?\323\370]\335\365\324\342?\375\376Gy\000\020\305\277\211\263M\261\357E\226?k;\211\300\304B\273?\252\026\375q\263\004\302?\021\342%\216\227\177\276?8\377\375n7\014\303\277V\014\265\222\276\340\327?\020N\010\001QG\201?\252h\025x\344P\334\277Y\345\010\372\242\024\247\277`M{\256\203P\313?tO\353v3\020\325?Ik\371\220&d\233?\010 @\272\372\032\303?\266\342\3453\263)\310\277\3239\232\376\256`\267\277\331a\315\315c,\263\277i\014\206J\307\243\207\277\021\223\320\002\232\242\244?\244\033\0168E2\332?RN\256\337+\014\\\277e\222\355\342\262\033|?\367\037\347\274G\026\315?\233\311]\361\240H\250\277\310\335E\244\361\201\201\277d\266kz\tu\257?\227\217\367[d6\322?r\004\214]\017\020\320\277\305+\202\327<\030\303?\177\277m\225\232T\323?q$\261g\022\264\312\277O\252]o1\327\320?\270\333\230N\242\202\271\277\301\334\356\312\242\213\317?bx\351\335\004\'\262?\270\347%c\352\215\306\277\376\r\207\336\372\rg?3\341\000\356\245\331\300\277\343\261\200g\361\007\204?\007\344<\017.?\331?\331p\232\337\3046\324?\200\272(\224\257\251\310?\203Wi\260\235\247\277?\347\257<oz/\263?:?\261\267CU\321\277\272@Q\253\374\t\312\277\274(h\216l@\300\277\326\327\234|\272\023\310\277\330/\344\332\345 \266\277\371\373\226\302@=\273?\307UZ$\372\222\265?u\363\302\3623\266\271?\3550X\247\340\273\312?\331\177}\022\343$\306?\304\347Td\305\031\325\277\t\311\373\260\367\216\322\277B_\224\343\331\370\324?\304\222l \337j\315?\335\013\224\270\264\335\266\277\003\257\274\377\350\310\304\277j\311sV\315\216\314\277\212._\342\222.\324\277w_Y\243\270>\273?\361\240\010%h7\273\277\244@#~\311\311\253?.\212\216\202k|\301?\207e\316\216\353\216\307?\255,\361\271\341\275\301\277\014\226\033\250\354C\265?\037\213\256U\231p\206\277\372\341\200\325=\005n\277\370\322\034*\376O\301\277\324\344\024\177\213\364\312?#1`\354\353\245\330\277\234\351>\t\330\266\304?\312\206T\217\321\006\303\277C\207\213\205\314\025\305\277\210OG5\307/\312\277\373\311\361,\030\245\340?\263\007\277\352\034\t\311\277\250\303A\237l\343\243\277Db\333E?\315\303?\326M\277\240Y3\300?j`\276\231/\244\316?\256(\362\026\277F\326\277GF\317\234\017\331\224?\372\300\204<\246T\271\277\312\010\323\263\245\234\333?S\200\214\205&\233\321\277;\354\337I\361\252\253\277\346;\226\356I\365\300?\3068\222xA#\322\2773q\241\204[\227\243\277S*\373@\322W\273?\275\3501\036O\272\303\277$\364\325/f\246\300?RAt\233\346\033\262?Y,\321p\345\252\301?\024\322\356\325\370\002\302?\367 ...
#    }
#    initializer {
#      dims: 20
#      dims: 7
#      data_type: 11
#      name: "Const_1:0"
#      raw_data: "\347-\220\231\233E\321?\334\006{W\304\255\325?\251\204\244(\354\324\264?l\346t\021\260\274\255?\3132\213\017\210\337\327?\254VaI\3672\300?\014.M\237%\255\272\277}*HV\257\372\320?\221\002tYg\300\277\277\277,\230\226As\342\277P[oZ\315\371\313\277.a\343\210\252D\335\277\003U\301\274\200\271\300\277\222\262\'\200\007 \275\277\341:\177\377[\022\303?\n\177<\230\366\215\323\277\027\321\217W\221r\300\277\n\000I\344\2248\233\277\262\350i\323\364^\236?\336AI\260\326\020\270\277yL\261\372{\360\245?/\340am\324\310\326?\362M4\314\302x\301\277\236\345\014\355B\242\335\277\361a\360\370\342\366\340\277)\356\305\314\017)\320?\310\253z\034\363n1?4\"\177\357\034\262\324\277\30718\311\371\207\272?\350\036\371\\]\037\245\277\215\274\022w\257\234\320?e\313\364\023\004 \341\277}\341i\0223.\311\277\366+\177\351\023\377\266?\325\\tg\n\344\326\277-M%\314\004\327\302?\302\205]\333\203\360\327?xO\340\031\257K\341?*~\027O\354M\343?\335\242\277?J@\304?\3143\0149\373\351\315?{\003\271\247\345\331\346?\332l\322\314\n\375\260?\356\035\372\006\337,\331?\302\261\203\335\024\273\261?]\262\224\014\365\246\313?\235\357\347\361\313\243\247?\354\276T\344\377/\221?\311\322r)\231\204\264\2770\322\214\3623f\324\277\3438\233\351Ll\314\277\274\324T\266\323j\304\277\313\230\211\021\373\205\273?Te\312\307\221\"\254?\307S\3363\261w\271\277\r\023}.HR\320\277\364\374_\264\331\256\311?\016\267#\326\203\326\327?\021\2631W\273\327\302?^S\362d\246\327\320?\27066Ioa\300?\336\366Y\234\350`\311\277\025\372\226p\331K\267?-\245\353=F\336\274?\372[e\317\004\242\340?\224\263\352\230\321~\341\277\230\022:\3429\001\240?\242 6\n^\350\274\277\361\216\323\300C\273\310?\326\026!\366f\227\211\277\'/X\333S\356\242?\224H4\204 \244\303?\216\225%\207\022\364\230\277Z\222Cx\367W\307?jX\3635\310J\303\277\303\325\350g\330\334\311?\241\220\321\001\000\014\260\277\246\211\244h^\204\322\277b\\\035tj\356\315?\0018\336\016\221\333\340?\272;\025g\372=\324?\247S\277\350V\223\322?\014s\013\344\317k\274?\256\223\247\325I\031\321?\376\272R\336\362\326\305?\370]\205\"\324\021\341?\351.\304Z&\360\341?\365-\342LIn\342?\020n_\346\276\300\263?m\031\254\204w\246\307?\\E\025\204\002\036\342?\270rj\361\312\262\244\277\250\3572.\354<\330?\324\275\251\251\315\326\346?\301&\277\306\203\337\300?^n?O\207-\322\2773I\354R\361\016\321?\307\275\224\0262\016\345?w\312\250(TM\272\277I\215\311\210\231=\324?\"\034w\307\356\235\323?\215<;\345\276\240\335?\305\005\204\251\212\260\234\277\366\022)p#d\302?\256Rm3\217\314\322?>\217\223!\214\360\310?\271\326\230\037#1\341?\373E_\212*\023\267?.\023\031\301\023\305\312?\363\254\247\363\343V\222\277\255\276\226\030\207M\227?\315\024O\226X%\330?\375\000\2364\214\211\262?\372\000*c\302a\322?\327\356\023T5R\260?\032U\365\262Q\t\265?t}5\037\234\351\300?\331\017]\242\234\002\314?,G$S\350\010\314?\277\214\022\325=\203\310\277\221\204Z\263\321\266\330\277\215\304\352]\242\273\304\277]\023\225\2102\226\307\277T\2316\273*,\332?\311O\035\372=\242\263\277\311O:x\0244\315\277\001\221\261\212w\263\307\277\332\307\204R`\023\317\277(\016\264[}\242\322\277\302\231\275\253\234\376\333\277\262}\014\221\013O\320\277\225\237\006\273\273\236\253\277\004f\336\232J\002\322\277\233\033,_\356#\272\277\007\267\251\305\306\320\330\277\204\267\307\234DP\320\277I\302qy\232B\257\277\253\247\177^G~\275\277\315\001\n~U\203\313\277\024Qs\003J-\347\277"
#    }
#    doc_string: "converted from b\'__inference_converted_fun_tf_32745\'"
#    input {
#      name: "args_tf_0"
#      type {
#        tensor_type {
#          elem_type: 11
#          shape {
#            dim {
#              dim_value: 1
#            }
#            dim {
#              dim_value: 7
#            }
#          }
#        }
#      }
#    }
#    output {
#      name: "Identity_1:0"
#      type {
#        tensor_type {
#          elem_type: 11
#          shape {
#            dim {
#              dim_value: 1
#            }
#          }
#        }
#      }
#    }
#  }
#  opset_import {
#    domain: ""
#    version: 15
#  }
#  opset_import {
#    domain: "ai.onnx.ml"
#    version: 2
#  },
#  None)
