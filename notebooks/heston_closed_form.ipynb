# %%
from typing import Sequence, Tuple, Union, Optional, Callable, Literal, Protocol
from jaxtyping import Array, ArrayLike, Float, Int, PyTree, PRNGKeyArray, ScalarLike


import jax
from jax import grad, jit, vmap
import jax.numpy as jnp
from jax import random as jrandom
import equinox as eqx

import optax


from functools import partial

from collections.abc import Generator
from typing_extensions import TypeAlias



from dataclasses import dataclass, asdict, astuple

# %%
print(jax.devices())
# Out:
# [CudaDevice(id=0)]

# %% [markdown]
# # Utils

# %%
class Range(eqx.Module):
    minval: float = 0.0
    maxval: float = 1.0

#class ModelState(eqx.Module):
#    S0: float
#    v0: float

class MakeScalar(eqx.Module):
    model: eqx.Module

    def __call__(self, *args, **kwargs):
        out = self.model(*args, **kwargs)
        return jnp.reshape(out, ())

# %%
import matplotlib.pyplot as plt

#def plot_differential_data(init_spots, init_vols, payoffs, states: ModelState):
#    # plt.plot(init_spots, payoffs, 'b.', markersize=1.0, label = 'payoffs')
#    plt.plot(init_spots, states.S0, 'r.', markersize=1.0, label = 'dpayoff/dS0')
#
#    print(init_spots.shape)
#    print(states.S0.shape)
#    # plt.plot(init_spots, states
#    # plt.plot(hset.initial_spot_prices, prices, 'r.', markersize=3, label='price')
#    plt.legend()
#    plt.xlabel('initial spot price')
#    plt.ylabel('payoff')
#    # plt.ylim(-1, 1000)
#    plt.show()

def plot_3d_differential_data(init_spots, init_vols, differential_data, label):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    sc = ax.scatter(init_spots, init_vols, differential_data, c=differential_data, cmap=plt.cm.viridis)
    
    # Add a colorbar to show the mapping of colors to z-values
    cbar = fig.colorbar(sc)
    cbar.set_label(label)
    
    ax.set_title(label)
    ax.set_xlabel("$S_0$")
    ax.set_ylabel("\nu_0")
    ax.set_zlabel(label)
    return fig

# %%
def mse(y_pred, y_true):
    return jnp.mean((jnp.array(y_pred) - jnp.array(y_true))**2)

def rmse(y_pred, y_true):
    return jnp.sqrt(mse(y_pred, y_true))

# %%
def normalize(x, x_mean, x_std):
    return (x - x_mean) / x_std

# %% [markdown]
# # HVP stuff

# %%
# HVP for single point and single direction from Bachelier
def hvp(f, x, v):
    return jax.jvp(lambda x_: eqx.filter_grad(f)(x_), (x,), (v,))[1]

# from bachelier
def hvp_batch(f, inputs, directions):
    """
    Compute Hessian-vector products: H(x_i) @ v_j
    Args:
        f: scalar-valued function f: R^n -> R
        inputs: [num_inputs, input_dim]
        directions: [num_directions, input_dim]
    Returns:
        hvps: [num_inputs, num_directions, input_dim]
    """
    def hvp_fn(x, v):
        return hvp(f, x, v)
    batched = eqx.filter_vmap(eqx.filter_vmap(hvp_fn, in_axes=(0, None)), in_axes=(None, 0))
    return jnp.transpose(batched(inputs, directions), (1, 0, 2))

# %% [markdown]
# # Payoff

# %%
class EuropeanPayoff:

    # TODO: naming: strike_prices should be strike_price unless we would like to support an array of strike prices
    @staticmethod
    def call(maturity_prices: Float[ArrayLike, " n"], strike_prices: Float[ScalarLike, ""]) -> Float[Array, " n"]:
        return jnp.maximum(jnp.subtract(maturity_prices, strike_prices), 0.0)

    @staticmethod
    def put(maturity_prices: Float[ArrayLike, " n"], strike_prices: Float[ScalarLike, ""]) -> Float[Array, " n"]:
        return jnp.maximum(jnp.subtract(strike_prices, maturity_prices), 0.0)

    @staticmethod
    def payoff(spot_path, K, payoff_fn = call):
        spot_maturity = spot_path[..., -1]
        payoff = payoff_fn(spot_maturity, K)
        return payoff


def european_payoff(spot_path, K, payoff_fn = EuropeanPayoff.call):
    spot_maturity = spot_path[..., -1]
    payoff = payoff_fn(spot_maturity, K)
    return payoff

def european_payoff_and_deriv(spot_path, K, payoff_fn = EuropeanPayoff.call):
    spot_maturity = spot_path[..., -1]
    # payoff = payoff_fn(spot_maturity, K)
    payoff, dpayoff = jax.value_and_grad(payoff_fn)(spot_maturity, K)
    return payoff, dpayoff

# %%
sharpness = 1e-3
bias = sharpness

def smooth_european_payoff(x, k):
    return jax.nn.celu(x=x-k, alpha=sharpness) + bias


fn = lambda x: jax.nn.celu(x=x, alpha=sharpness) + bias
smooth_max_fn = fn

# %% [markdown]
# # Heston

# %%
#class ModelState(eqx.Module):
#    S0: float
#    v0: float

## just for testing
#class DDModelState(eqx.Module):
#    S0: ModelState
#    v0: ModelState

    
class Heston(eqx.Module):


    spot_range:Range = Range(50.0, 150.0)
    vol_range: Range = Range(0.01, 0.1)

    mc_time_steps: int = 1024 # number of time steps for the Monte Carlo simulation
     
    K: float = 100.0        # Strike price
    r: float = 0.05         # Risk-free rate
    T: float = 5.0          # n years until expiry, i.e. T2 - T1
    rho: float = -0.3       # Correlation of asset and volatility
    kappa: float = 2.00     # Mean-reversion rate
    theta: float = 0.09     # Long run average volatility
    xi: float = 1.00        # Volatility of volatility


    # for semi-closed-form solution
    num_w: int = 512
    w_max: float = 100.0

    

    def closed_form_price(self, S0, v0):
        """
        Compute the Heston model European call price using the semi-closed-form solution using numerical integration in JAX.

        Math from:  https://www.ma.imperial.ac.uk/~ajacquie/IC_Num_Methods/IC_Num_Methods_Docs/Literature/Heston.pdf
        and form:   https://xilinx.github.io/Vitis_Libraries/quantitative_finance/2019.2/methods/cf-ht.html#chrso2014
        
        Parameters:
        - S0: initial spot price
        - v0: initial variance
       
        Returns:
        - call option price under Heston model
        """

        sigma = self.xi # volatility of volatility

        # integration grid
        w = jnp.linspace(0.0, self.w_max, self.num_w)[1:]  # avoid w=0

        # Heston characteristic function components
        a = self.kappa * self.theta
        def C_D(wi):
            alpha = -0.5 * wi**2 - 0.5j * wi
            beta  = alpha - 1j * self.rho * sigma * wi
            gamma = 0.5 * sigma**2

            h = jnp.sqrt(beta**2 - 4 * alpha * gamma)
            rp = (beta + h) / (sigma**2)
            rm = (beta - h) / (sigma**2)
            g = rm / rp

            exp_neg_ht = jnp.exp(-h * self.T)
            C = a * (rm * self.T - (2.0 / sigma**2) * jnp.log((1 - g * exp_neg_ht) / (1 - g)))
            D = rm * (1 - exp_neg_ht) / (1 - g * exp_neg_ht)
            return C, D

        # vectorize C and D over w
        C_vec, D_vec = jax.vmap(C_D)(w)

        # characteristic function Psi
        log_term = jnp.log(S0) + self.r * self.T
        def Psi(wi, Ci, Di):
            return jnp.exp(Ci * self.theta + Di * v0 + 1j * wi * log_term)

        Psi_w      = Psi(w,      C_vec, D_vec)
        Psi_w_minus_i = Psi(w - 1j, *jax.vmap(C_D)(w - 1j))
        Psi_minus_i = Psi(-1j, *C_D(-1j))

        # integrands for Pi1 and Pi2
        integrand1 = jnp.real(jnp.exp(-1j * w * jnp.log(self.K)) * Psi_w_minus_i / (1j * w * Psi_minus_i))
        integrand2 = jnp.real(jnp.exp(-1j * w * jnp.log(self.K)) * Psi_w      / (1j * w))

        # numerical integration via the trapezoidal rule
        Pi1 = 0.5 + (1.0 / jnp.pi) * jnp.trapezoid(integrand1, w)
        Pi2 = 0.5 + (1.0 / jnp.pi) * jnp.trapezoid(integrand2, w)

        # final price
        price = S0 * Pi1 - jnp.exp(-self.r * self.T) * self.K * Pi2
        return price




    
    def hessian_2x2_for_one_closed_form(self, initial_spots, initial_vols):
        def f_s0v0(x):
            s0, v0 = x
            return self.closed_form_price(S0=s0, v0=v0)
        
        hvps = hvp_batch(
            f=f_s0v0,
            # NOTE this is where later the extra basket dim can be added
            inputs=jnp.array([(initial_spots, initial_vols)]), 
            directions=jnp.array([[1.0, 0.0], [0.0, 1.0]]) 
        )
        
        H_block = jnp.transpose(hvps[0], (1,0))

        return H_block




    def sample_data_closed_form(self, key, n_samples=256):    
        

        key, key_state = jrandom.split(key)
        
        minvals=jnp.array([self.spot_range.minval, self.vol_range.minval])
        maxvals=jnp.array([self.spot_range.maxval, self.vol_range.maxval])
        
        
        initial_states = jrandom.uniform(key_state, shape=(n_samples, 2), minval=minvals, maxval=maxvals)
        #print("initial_states shape train:", initial_states.shape)

        initial_spots = initial_states[:, 0]
        initial_vols = initial_states[:, 1]

        value_and_grad_fn = jax.value_and_grad(self.closed_form_price, argnums=(0,1))
        y, (dS0, dV0) = jax.vmap(value_and_grad_fn)(initial_spots, initial_vols)
        dydx = jnp.array([dS0, dV0]).T  # shape (batch_size, 2)
        #print("x shape: ", initial_states.shape) # (batch_size, 2)
        #print("y shape: ", y.shape) # (batch_size,)
        #print("dydx shape: ", dydx.shape) # (batch_size, 2)
        
        ddyddx = jax.vmap(self.hessian_2x2_for_one_closed_form, in_axes=(0, 0))(initial_spots, initial_vols)        
        #print("ddyddx shape: ", ddyddx.shape) # (batch_size, 2, 2)


        # Normalize the data
        x_mean = jnp.mean(initial_states, axis=0)
        x_std = jnp.std(initial_states, axis=0)
        y_mean = jnp.mean(y)
        y_std = jnp.std(y)
        x = normalize(initial_states, x_mean, x_std)
        y = normalize(y, y_mean, y_std)
        # TODO understand why this is needed
        dydx_scaled = (x_std / y_std) * dydx
        ddyddx_scaled = (jnp.outer(x_std, x_std) / y_std) * ddyddx

        x = initial_states
        return x, y, dydx_scaled, ddyddx_scaled

# %% [markdown]
# test closed form

# %%
key = jrandom.PRNGKey(0)

ref_model = Heston(
    spot_range = Range(50.0, 150.0),
    vol_range = Range(0.01, 0.1),
    mc_time_steps=1024,
    K= 100.0,
    r = 0.00,
    T = 1.0,
    rho = -0.3,
    kappa = 1.0,
    theta = 0.09,
    xi = 1.0
)

# %% [markdown]
# test closed form

# %%
closed_form_vis_batch = ref_model.sample_data_closed_form(key, n_samples=512)
test_set = ref_model.sample_data_closed_form(key, n_samples=512)
print("test_set shapes:", test_set[0].shape, test_set[1].shape, test_set[2].shape, test_set[3].shape)
# Out:
# x shape:  (512, 2)
# y shape:  (512,)
# dydx shape:  (512, 2)
# ddyddx shape:  (512, 2, 2)
# x shape:  (512, 2)
# y shape:  (512,)
# dydx shape:  (512, 2)
# ddyddx shape:  (512, 2, 2)

# %%
xs = closed_form_vis_batch[0][..., 0]
ys = closed_form_vis_batch[0][..., 1]

ps = closed_form_vis_batch[1]
dps = closed_form_vis_batch[2]
ddps = closed_form_vis_batch[3]

fig_payoff = plot_3d_differential_data(xs, ys, ps, "CF payoff\ntrain target")

fig_dS = plot_3d_differential_data(xs, ys, dps[:, 0], "CF 1st-order diff payoff - dS\ntrain target")
fig_dv = plot_3d_differential_data(xs, ys, dps[:, 1], "CF 1st-order diff payoff - dv\ntrain target")

fig_dS = plot_3d_differential_data(xs, ys, ddps[:, 0, 0], "CF 2nd-order diff payoff - dSdS\ntrain target")
fig_dv = plot_3d_differential_data(xs, ys, ddps[:, 0, 1], "CF 2nd-order diff payoff - dSdv\ntrain target")
fig_dS = plot_3d_differential_data(xs, ys, ddps[:, 1, 0], "CF 2nd-order diff payoff - dvdS\ntrain target")
fig_dv = plot_3d_differential_data(xs, ys, ddps[:, 1, 1], "CF 2nd-order diff payoff - dvdv\ntrain target")

# %% [markdown]
# # Learning

# %% [markdown]
# ### Model

# %%
def trunc_init(weight: Array, key: jax.random.PRNGKey) -> Array:
  out, in_ = weight.shape
  stddev = jnp.sqrt(1 / in_)
  return jax.nn.initializers.glorot_normal()(key, (out, in_))

def init_linear_weight(model, init_fn, key):
  is_linear = lambda x: isinstance(x, eqx.nn.Linear)
  get_weights = lambda m: [x.weight
                           for x in jax.tree_util.tree_leaves(m, is_leaf=is_linear)
                           if is_linear(x)]
  weights = get_weights(model)
  new_weights = [init_fn(weight, subkey)
                 for weight, subkey in zip(weights, jax.random.split(key, len(weights)))]
  new_model = eqx.tree_at(get_weights, model, new_weights)
  return new_model

# %% [markdown]
# ### Loss Functions

# %%
def standard_loss_fn(model, batch):
    x = batch[0]
    y = batch[1]
    y_pred = vmap(model)(x)
    return mse(y, y_pred)


@eqx.filter_jit
def second_order_loss_fn(model: eqx.nn.MLP, batch) -> Float:
    
    #batch = ref_model.sample_data(key, batch_size)
        
    x = batch[0]
    y = batch[1]
    dydx = batch[2]
    ddyddx = batch[3]

    #print("x shape: ", x.shape)
    #print("y shape: ", y.shape)
    #print("dydx shape: ", dydx.shape)
    #print("ddyddx shape: ", ddyddx.shape)
    #print("")
    #return .0


    # TODO normalization ?
    #x = (x - x_mean) / x_std
    #y = (y - y_mean) / y_std
    
    # TODO loss balancing
    #lam = 1
    #n_dims = model.in_size
    #lambda_scale = lam * n_dims
    #alpha = 1.0/(1.0 + lambda_scale)
    #beta = lambda_scale/(1.0 + lambda_scale)
    #gamma = 0.0

    alpha = 1/3
    beta = 1/3
    gamma = 1/3
    
    #alpha = 0.2
    #beta = 0.6
    #gamma = 0.2
    
    
    y_pred, dydx_pred = vmap(eqx.filter_value_and_grad(model))(x)
    assert(y_pred.shape == y.shape)
    assert(dydx_pred.shape == dydx.shape)
    
    #print("y_pred shape: ", y_pred.shape)
    #print("dydx_pred shape: ", dydx_pred.shape)
    #print("")
    #return .0

    ddyddx_pred = vmap(jax.hessian(MakeScalar(model)))(x)
    assert(ddyddx_pred.shape == ddyddx.shape)
    
    #print("ddyddx_pred shape: ", ddyddx_pred.shape)
    #print("")
    #return .0



    value_loss = mse(y_pred, y)
    grad_loss = mse(dydx_pred, dydx) 
    hess_loss = mse(ddyddx_pred, ddyddx)
    #hess_loss = 0


    #jax.debug.print("value loss: {}", value_loss)
    #jax.debug.print("grad loss: {}", grad_loss)
    #jax.debug.print("hess loss: {}", hess_loss)
    #jax.debug.print("---------------------------------")
    
    
    loss = alpha * value_loss + beta * grad_loss + gamma * hess_loss
    
    return loss

# %% [markdown]
# ### Train

# %%
from itertools import islice

Data: TypeAlias = dict[str, Float[Array, "n_samples ..."]]
DataGenerator: TypeAlias = Generator[Data, None, None]


def train(
    model: PyTree,
    test_data: Tuple,
    optim: optax.GradientTransformation,
    n_epochs: int,
    n_batches_per_epoch: int,
    batch_size: int,
    key: PRNGKeyArray,
) -> PyTree:
    

    @eqx.filter_jit
    def train_step(model: PyTree, opt_state: PyTree, batch_size: int):
        
        batch = ref_model.sample_data_closed_form(key, batch_size)

        #loss_value, grads = eqx.filter_value_and_grad(standard_loss_fn)(model, batch)
        loss_value, grads = eqx.filter_value_and_grad(second_order_loss_fn)(model, batch)
        
        
        updates, opt_state = optim.update(grads, opt_state, model)
        model = eqx.apply_updates(model, updates)
        return model, opt_state, loss_value

    opt_state = optim.init(eqx.filter(model, eqx.is_array))
    train_loss = jnp.zeros(1)

    n_steps = n_epochs * n_batches_per_epoch
    print(f"Training for {n_epochs} epochs with {n_batches_per_epoch} batches per epoch and batch size {batch_size}.")
    
    keys = jrandom.split(key, n_steps)

    for i, key in enumerate(keys):
        
        
        # print(i)
        # print(batch["normalized_initial_states"])
        # print(batch["normalized_payoffs"].shape)
        with jax.profiler.StepTraceAnnotation("Train Step", step_num=i):  

            model, opt_state, train_loss = train_step(model, opt_state, batch_size)
        
        if i % n_batches_per_epoch == 0:
            epoch_stats = f"Finished epoch {int(i/n_batches_per_epoch)+1} | Train Loss: {train_loss:.5f}"    

            # test data evaluation
            if test_data:
                test_pred_ys, test_pred_dys = vmap(jax.value_and_grad(model))(test_set[0])
                #test_pred_ddys = vmap(jax.hessian(MakeScalar(model)))(test_set[0])
                y_error = jnp.sqrt(mse(test_pred_ys, test_set[1]))
                #dy_error = jnp.sqrt(mse(test_pred_dys, test_set[2]))
                #ddy_error = jnp.sqrt(mse(test_pred_ddys, test_set[3]))
                test_loss = y_error # (y_error + dy_error + ddy_error) / 3.0
                epoch_stats += f" | Test Loss: {test_loss:.5f}"
            
            print(epoch_stats)

            
    return model

# %%
key = jrandom.PRNGKey(0)
key, subkey = jrandom.split(key)

# in_size is 2 for initial_spot and initial_vol
n_dims = 2
mlp = eqx.nn.MLP(key=subkey, in_size=n_dims, out_size="scalar", width_size=20, depth=3, activation=jax.nn.elu)

key, subkey = jax.random.split(key)
mlp = init_linear_weight(mlp, trunc_init, key)
surrogate_model = mlp

# %%
n_epochs = 200
n_batches_per_epoch = 32
BATCH_SIZE = 512

# NOTE batch:_size * n_batches_per_epoch = 8192

key = jrandom.PRNGKey(0)

ref_model = Heston(
    spot_range = Range(50.0, 150.0),
    vol_range = Range(0.01, 0.1),
    mc_time_steps=1024,
    K= 100.0,
    r = 0.00,
    T = 1.0,
    rho = -0.3,
    kappa = 1.0,
    theta = 0.09,
    xi = 1.0
)


#train_dataset = ds
#generator_train_ds = generator_train_data(train_dataset, batch_size=BATCH_SIZE)
#generator_test_ds = None
# total_steps = n_epochs * (len(ds["payoffs"]) // BATCH_SIZE) + n_epochs

# total_steps = 64 * n_epochs
# lr_schedule = optax.exponential_decay(init_value=0.01, transition_steps=total_steps, transition_begin=int(total_steps*0.2), decay_rate=0.9)
# optim = optax.adam(learning_rate=lr_schedule)
optim = optax.adam(learning_rate=1e-3) # 3e-4 was default


surrogate_model = train(
                        model = surrogate_model, 
                        test_data=test_set,
                        optim=optim, 
                        n_epochs=n_epochs,
                        n_batches_per_epoch=n_batches_per_epoch,
                        batch_size=BATCH_SIZE,
                        key=key
                        )
# Out:
# Training for 200 epochs with 32 batches per epoch and batch size 512.
# Finished epoch 1 | Train Loss: 285.23859 | Test Loss: 28.30441
# Finished epoch 2 | Train Loss: 9.61775 | Test Loss: 4.73247
# Finished epoch 3 | Train Loss: 1.35689 | Test Loss: 1.81363
# Finished epoch 4 | Train Loss: 0.89710 | Test Loss: 1.42589
# Finished epoch 5 | Train Loss: 0.52785 | Test Loss: 0.95357
# Finished epoch 6 | Train Loss: 0.33029 | Test Loss: 0.60061
# Finished epoch 7 | Train Loss: 0.26233 | Test Loss: 0.41692
# Finished epoch 8 | Train Loss: 0.23393 | Test Loss: 0.30969
# Finished epoch 9 | Train Loss: 0.22152 | Test Loss: 0.25457
# Finished epoch 10 | Train Loss: 0.21698 | Test Loss: 0.23609
# Finished epoch 11 | Train Loss: 0.21547 | Test Loss: 0.23091
# Finished epoch 12 | Train Loss: 0.21491 | Test Loss: 0.22972
# Finished epoch 13 | Train Loss: 0.21469 | Test Loss: 0.23090
# Finished epoch 14 | Train Loss: 0.21405 | Test Loss: 0.22336
# Finished epoch 15 | Train Loss: 0.21362 | Test Loss: 0.22287
# Finished epoch 16 | Train Loss: 0.21335 | Test Loss: 0.22207
# Finished epoch 17 | Train Loss: 0.21309 | Test Loss: 0.22088
# Finished epoch 18 | Train Loss: 0.21285 | Test Loss: 0.21876
# Finished epoch 19 | Train Loss: 0.21249 | Test Loss: 0.21759
# Finished epoch 20 | Train Loss: 0.21181 | Test Loss: 0.21251
# Finished epoch 21 | Train Loss: 0.21085 | Test Loss: 0.20313
# Finished epoch 22 | Train Loss: 0.20995 | Test Loss: 0.19406
# Finished epoch 23 | Train Loss: 0.20790 | Test Loss: 0.17646
# Finished epoch 24 | Train Loss: 0.20596 | Test Loss: 0.16008
# Finished epoch 25 | Train Loss: 0.20379 | Test Loss: 0.13755
# Finished epoch 26 | Train Loss: 0.20244 | Test Loss: 0.12407
# Finished epoch 27 | Train Loss: 0.20169 | Test Loss: 0.11873
# Finished epoch 28 | Train Loss: 0.20119 | Test Loss: 0.11708
# Finished epoch 29 | Train Loss: 0.20076 | Test Loss: 0.11179
# Finished epoch 30 | Train Loss: 0.20057 | Test Loss: 0.11231
# Finished epoch 31 | Train Loss: 0.20036 | Test Loss: 0.11405
# Finished epoch 32 | Train Loss: 0.20017 | Test Loss: 0.11019
# Finished epoch 33 | Train Loss: 0.20006 | Test Loss: 0.10887
# Finished epoch 34 | Train Loss: 0.19996 | Test Loss: 0.11104
# Finished epoch 35 | Train Loss: 0.19992 | Test Loss: 0.10984
# Finished epoch 36 | Train Loss: 0.19985 | Test Loss: 0.11031
# Finished epoch 37 | Train Loss: 0.19978 | Test Loss: 0.11111
# Finished epoch 38 | Train Loss: 0.19973 | Test Loss: 0.11057
# Finished epoch 39 | Train Loss: 0.19972 | Test Loss: 0.10968
# Finished epoch 40 | Train Loss: 0.19978 | Test Loss: 0.11435
# Finished epoch 41 | Train Loss: 0.19969 | Test Loss: 0.11195
# Finished epoch 42 | Train Loss: 0.19959 | Test Loss: 0.11166
# Finished epoch 43 | Train Loss: 0.19975 | Test Loss: 0.11970
# Finished epoch 44 | Train Loss: 0.19973 | Test Loss: 0.11367
# Finished epoch 45 | Train Loss: 0.19952 | Test Loss: 0.11520
# Finished epoch 46 | Train Loss: 0.19948 | Test Loss: 0.10987
# Finished epoch 47 | Train Loss: 0.19952 | Test Loss: 0.12357
# Finished epoch 48 | Train Loss: 0.19946 | Test Loss: 0.11440
# Finished epoch 49 | Train Loss: 0.19947 | Test Loss: 0.11543
# Finished epoch 50 | Train Loss: 0.19941 | Test Loss: 0.11230
# Finished epoch 51 | Train Loss: 0.19944 | Test Loss: 0.11174
# Finished epoch 52 | Train Loss: 0.19952 | Test Loss: 0.11147
# Finished epoch 53 | Train Loss: 0.19935 | Test Loss: 0.12964
# Finished epoch 54 | Train Loss: 0.19964 | Test Loss: 0.11404
# Finished epoch 55 | Train Loss: 0.19989 | Test Loss: 0.11172
# Finished epoch 56 | Train Loss: 0.19951 | Test Loss: 0.11964
# Finished epoch 57 | Train Loss: 0.19930 | Test Loss: 0.12012
# Finished epoch 58 | Train Loss: 0.19937 | Test Loss: 0.11312
# Finished epoch 59 | Train Loss: 0.19936 | Test Loss: 0.11411
# Finished epoch 60 | Train Loss: 0.19930 | Test Loss: 0.11963
# Finished epoch 61 | Train Loss: 0.19931 | Test Loss: 0.11361
# Finished epoch 62 | Train Loss: 0.19936 | Test Loss: 0.11640
# Finished epoch 63 | Train Loss: 0.19959 | Test Loss: 0.11726
# Finished epoch 64 | Train Loss: 0.19931 | Test Loss: 0.11362
# Finished epoch 65 | Train Loss: 0.19926 | Test Loss: 0.11660
# Finished epoch 66 | Train Loss: 0.19927 | Test Loss: 0.11698
# Finished epoch 67 | Train Loss: 0.19926 | Test Loss: 0.11650
# Finished epoch 68 | Train Loss: 0.19935 | Test Loss: 0.12995
# Finished epoch 69 | Train Loss: 0.19943 | Test Loss: 0.11961
# Finished epoch 70 | Train Loss: 0.19926 | Test Loss: 0.11355
# Finished epoch 71 | Train Loss: 0.19943 | Test Loss: 0.11365
# Finished epoch 72 | Train Loss: 0.19929 | Test Loss: 0.11395
# Finished epoch 73 | Train Loss: 0.19945 | Test Loss: 0.11405
# Finished epoch 74 | Train Loss: 0.19918 | Test Loss: 0.11901
# Finished epoch 75 | Train Loss: 0.19919 | Test Loss: 0.12143
# Finished epoch 76 | Train Loss: 0.19916 | Test Loss: 0.11519
# Finished epoch 77 | Train Loss: 0.19943 | Test Loss: 0.12536
# Finished epoch 78 | Train Loss: 0.19921 | Test Loss: 0.11774
# Finished epoch 79 | Train Loss: 0.19917 | Test Loss: 0.11698
# Finished epoch 80 | Train Loss: 0.19919 | Test Loss: 0.11868
# Finished epoch 81 | Train Loss: 0.19921 | Test Loss: 0.11450
# Finished epoch 82 | Train Loss: 0.19918 | Test Loss: 0.12176
# Finished epoch 83 | Train Loss: 0.19932 | Test Loss: 0.11485
# Finished epoch 84 | Train Loss: 0.19916 | Test Loss: 0.12356
# Finished epoch 85 | Train Loss: 0.19915 | Test Loss: 0.11432
# Finished epoch 86 | Train Loss: 0.19914 | Test Loss: 0.11645
# Finished epoch 87 | Train Loss: 0.19922 | Test Loss: 0.11753
# Finished epoch 88 | Train Loss: 0.19949 | Test Loss: 0.11575
# Finished epoch 89 | Train Loss: 0.19914 | Test Loss: 0.11856
# Finished epoch 90 | Train Loss: 0.19917 | Test Loss: 0.11714
# Finished epoch 91 | Train Loss: 0.19912 | Test Loss: 0.12060
# Finished epoch 92 | Train Loss: 0.19911 | Test Loss: 0.12019
# Finished epoch 93 | Train Loss: 0.19915 | Test Loss: 0.12750
# Finished epoch 94 | Train Loss: 0.19911 | Test Loss: 0.11624
# Finished epoch 95 | Train Loss: 0.19920 | Test Loss: 0.11761
# Finished epoch 96 | Train Loss: 0.19913 | Test Loss: 0.11934
# Finished epoch 97 | Train Loss: 0.19945 | Test Loss: 0.11793
# Finished epoch 98 | Train Loss: 0.19938 | Test Loss: 0.11711
# Finished epoch 99 | Train Loss: 0.19910 | Test Loss: 0.11938
# Finished epoch 100 | Train Loss: 0.19923 | Test Loss: 0.12141
# Finished epoch 101 | Train Loss: 0.19914 | Test Loss: 0.12111
# Finished epoch 102 | Train Loss: 0.19933 | Test Loss: 0.12276
# Finished epoch 103 | Train Loss: 0.19934 | Test Loss: 0.11786
# Finished epoch 104 | Train Loss: 0.19927 | Test Loss: 0.11943
# Finished epoch 105 | Train Loss: 0.19914 | Test Loss: 0.11630
# Finished epoch 106 | Train Loss: 0.19918 | Test Loss: 0.11833
# Finished epoch 107 | Train Loss: 0.19914 | Test Loss: 0.12384
# Finished epoch 108 | Train Loss: 0.19916 | Test Loss: 0.12371
# Finished epoch 109 | Train Loss: 0.19908 | Test Loss: 0.12320
# Finished epoch 110 | Train Loss: 0.19907 | Test Loss: 0.12023
# Finished epoch 111 | Train Loss: 0.19919 | Test Loss: 0.11696
# Finished epoch 112 | Train Loss: 0.19950 | Test Loss: 0.11693
# Finished epoch 113 | Train Loss: 0.19917 | Test Loss: 0.13727
# Finished epoch 114 | Train Loss: 0.19908 | Test Loss: 0.12485
# Finished epoch 115 | Train Loss: 0.19914 | Test Loss: 0.14283
# Finished epoch 116 | Train Loss: 0.19911 | Test Loss: 0.12734
# Finished epoch 117 | Train Loss: 0.19906 | Test Loss: 0.12706
# Finished epoch 118 | Train Loss: 0.19950 | Test Loss: 0.11682
# Finished epoch 119 | Train Loss: 0.19917 | Test Loss: 0.12780
# Finished epoch 120 | Train Loss: 0.19911 | Test Loss: 0.11859
# Finished epoch 121 | Train Loss: 0.19904 | Test Loss: 0.12432
# Finished epoch 122 | Train Loss: 0.19924 | Test Loss: 0.11732
# Finished epoch 123 | Train Loss: 0.19923 | Test Loss: 0.11656
# Finished epoch 124 | Train Loss: 0.19929 | Test Loss: 0.11861
# Finished epoch 125 | Train Loss: 0.19912 | Test Loss: 0.13132
# Finished epoch 126 | Train Loss: 0.19906 | Test Loss: 0.13225
# Finished epoch 127 | Train Loss: 0.19910 | Test Loss: 0.11700
# Finished epoch 128 | Train Loss: 0.19902 | Test Loss: 0.12987
# Finished epoch 129 | Train Loss: 0.19901 | Test Loss: 0.12287
# Finished epoch 130 | Train Loss: 0.19903 | Test Loss: 0.12044
# Finished epoch 131 | Train Loss: 0.19901 | Test Loss: 0.12506
# Finished epoch 132 | Train Loss: 0.19899 | Test Loss: 0.11782
# Finished epoch 133 | Train Loss: 0.19900 | Test Loss: 0.11841
# Finished epoch 134 | Train Loss: 0.19918 | Test Loss: 0.11790
# Finished epoch 135 | Train Loss: 0.19915 | Test Loss: 0.12194
# Finished epoch 136 | Train Loss: 0.19902 | Test Loss: 0.12352
# Finished epoch 137 | Train Loss: 0.19901 | Test Loss: 0.12011
# Finished epoch 138 | Train Loss: 0.19900 | Test Loss: 0.12142
# Finished epoch 139 | Train Loss: 0.19913 | Test Loss: 0.13683
# Finished epoch 140 | Train Loss: 0.19904 | Test Loss: 0.11705
# Finished epoch 141 | Train Loss: 0.19921 | Test Loss: 0.11737
# Finished epoch 142 | Train Loss: 0.19949 | Test Loss: 0.13935
# Finished epoch 143 | Train Loss: 0.19907 | Test Loss: 0.12034
# Finished epoch 144 | Train Loss: 0.19971 | Test Loss: 0.12038
# Finished epoch 145 | Train Loss: 0.19958 | Test Loss: 0.11858
# Finished epoch 146 | Train Loss: 0.19902 | Test Loss: 0.12462
# Finished epoch 147 | Train Loss: 0.19901 | Test Loss: 0.13236
# Finished epoch 148 | Train Loss: 0.19902 | Test Loss: 0.12044
# Finished epoch 149 | Train Loss: 0.19904 | Test Loss: 0.11857
# Finished epoch 150 | Train Loss: 0.19898 | Test Loss: 0.11892
# Finished epoch 151 | Train Loss: 0.19899 | Test Loss: 0.11881
# Finished epoch 152 | Train Loss: 0.19910 | Test Loss: 0.12629
# Finished epoch 153 | Train Loss: 0.19900 | Test Loss: 0.11758
# Finished epoch 154 | Train Loss: 0.19903 | Test Loss: 0.12094
# Finished epoch 155 | Train Loss: 0.19900 | Test Loss: 0.12436
# Finished epoch 156 | Train Loss: 0.19905 | Test Loss: 0.11863
# Finished epoch 157 | Train Loss: 0.19905 | Test Loss: 0.12173
# Finished epoch 158 | Train Loss: 0.19928 | Test Loss: 0.12832
# Finished epoch 159 | Train Loss: 0.19900 | Test Loss: 0.12218
# Finished epoch 160 | Train Loss: 0.19903 | Test Loss: 0.12039
# Finished epoch 161 | Train Loss: 0.19900 | Test Loss: 0.12117
# Finished epoch 162 | Train Loss: 0.19954 | Test Loss: 0.11692
# Finished epoch 163 | Train Loss: 0.19900 | Test Loss: 0.12068
# Finished epoch 164 | Train Loss: 0.19917 | Test Loss: 0.11759
# Finished epoch 165 | Train Loss: 0.19912 | Test Loss: 0.11682
# Finished epoch 166 | Train Loss: 0.19905 | Test Loss: 0.13266
# Finished epoch 167 | Train Loss: 0.19922 | Test Loss: 0.11661
# Finished epoch 168 | Train Loss: 0.19901 | Test Loss: 0.13175
# Finished epoch 169 | Train Loss: 0.19901 | Test Loss: 0.12808
# Finished epoch 170 | Train Loss: 0.19910 | Test Loss: 0.12144
# Finished epoch 171 | Train Loss: 0.19900 | Test Loss: 0.12259
# Finished epoch 172 | Train Loss: 0.19959 | Test Loss: 0.13119
# Finished epoch 173 | Train Loss: 0.19898 | Test Loss: 0.12143
# Finished epoch 174 | Train Loss: 0.19915 | Test Loss: 0.13102
# Finished epoch 175 | Train Loss: 0.19917 | Test Loss: 0.11715
# Finished epoch 176 | Train Loss: 0.19911 | Test Loss: 0.11735
# Finished epoch 177 | Train Loss: 0.19929 | Test Loss: 0.13002
# Finished epoch 178 | Train Loss: 0.19960 | Test Loss: 0.11711
# Finished epoch 179 | Train Loss: 0.20003 | Test Loss: 0.11718
# Finished epoch 180 | Train Loss: 0.19909 | Test Loss: 0.11684
# Finished epoch 181 | Train Loss: 0.19918 | Test Loss: 0.12027
# Finished epoch 182 | Train Loss: 0.19923 | Test Loss: 0.11862
# Finished epoch 183 | Train Loss: 0.19960 | Test Loss: 0.13850
# Finished epoch 184 | Train Loss: 0.19971 | Test Loss: 0.12674
# Finished epoch 185 | Train Loss: 0.19985 | Test Loss: 0.12070
# Finished epoch 186 | Train Loss: 0.19906 | Test Loss: 0.12529
# Finished epoch 187 | Train Loss: 0.19972 | Test Loss: 0.13186
# Finished epoch 188 | Train Loss: 0.19902 | Test Loss: 0.12172
# Finished epoch 189 | Train Loss: 0.19912 | Test Loss: 0.11726
# Finished epoch 190 | Train Loss: 0.19916 | Test Loss: 0.12972
# Finished epoch 191 | Train Loss: 0.19912 | Test Loss: 0.12230
# Finished epoch 192 | Train Loss: 0.19935 | Test Loss: 0.13816
# Finished epoch 193 | Train Loss: 0.19899 | Test Loss: 0.12125
# Finished epoch 194 | Train Loss: 0.19917 | Test Loss: 0.12400
# Finished epoch 195 | Train Loss: 0.19899 | Test Loss: 0.11862
# Finished epoch 196 | Train Loss: 0.19899 | Test Loss: 0.12751
# Finished epoch 197 | Train Loss: 0.19898 | Test Loss: 0.12103
# Finished epoch 198 | Train Loss: 0.19899 | Test Loss: 0.12131
# Finished epoch 199 | Train Loss: 0.19915 | Test Loss: 0.12037
# Finished epoch 200 | Train Loss: 0.19899 | Test Loss: 0.12044

# %%
# eval price predictions
test_pred_ys, test_pred_dys = vmap(jax.value_and_grad(surrogate_model))(test_set[0])
test_pred_ddys = vmap(jax.hessian(MakeScalar(surrogate_model)))(test_set[0])

# %%
y_error = jnp.sqrt(mse(test_pred_ys, test_set[1]))
dy_error = jnp.sqrt(mse(test_pred_dys, test_set[2]))
ddy_error = jnp.sqrt(mse(test_pred_ddys, test_set[3]))

print(f"test y error: {y_error:.4f}")
print(f"test dy error: {dy_error:.4f}")
print(f"test ddy error: {ddy_error:.4f}")
# Out:
# test y error: 0.1314
# test dy error: 0.7111
# test ddy error: 0.2371

# %%
# plot the predictions
xs = test_set[0][:, 0]
ys = test_set[0][:, 1]

fig_payoff = plot_3d_differential_data(xs, ys, test_pred_ys, "payoff\ntest predictions")

fig_dS = plot_3d_differential_data(xs, ys, test_pred_dys[:, 0], "1st-order diff payoff - dS0\ntest predictions")
fig_dv = plot_3d_differential_data(xs, ys, test_pred_dys[:, 1], "1st-order diff payoff - dv0\ntest predictions")

fig_dS = plot_3d_differential_data(xs, ys, test_pred_ddys[:, 0, 0], "2nd-order diff payoff - dS0dS0\ntest predictions")
fig_dv = plot_3d_differential_data(xs, ys, test_pred_ddys[:, 0, 1], "2nd-order diff payoff - dS0dv0\ntest predictions")
fig_dS = plot_3d_differential_data(xs, ys, test_pred_ddys[:, 1, 0], "2nd-order diff payoff - dv0dS0\ntest predictions")
fig_dv = plot_3d_differential_data(xs, ys, test_pred_ddys[:, 1, 1], "2nd-order diff payoff - dv0dv0\ntest predictions")
